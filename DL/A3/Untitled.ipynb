# %%
import numpy as np
import torch
import os
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
from sklearn import decomposition
from PIL import Image
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
image = Image.open('Scissor_Tailed_Flycatcher_0002_41762.jpg')
image.resize((28,28))
np.shape(image)

# %%
from PIL import Image  
  
# Opens a image in RGB mode  
# im = Image.open('Yellow_Bellied_Flycatcher_0001_795488.jpg') 
im = Image.open('Scissor_Tailed_Flycatcher_0002_41762.jpg')
plt.imshow(im)
plt.show() 

width, height = im.size  
left = width/10
top = height / 10
right = 9*width/10
bottom = 9* height / 10
im1 = im.crop((left, top, right, bottom)) 

newsize = (100, 100) 
im1 = im1.resize(newsize) 
plt.imshow(im1)
plt.show()

# %%
np.shape(im1)
# Out:
# (200, 200, 3)

# %%
image = Image.open('Yellow_Bellied_Flycatcher_0001_795488.jpg')
bird = np.asarray(image,dtype="int16")
np.shape(bird)
