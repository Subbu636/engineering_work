# %%
# imports

import gym
import random as rd
from collections import deque
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %% [markdown]
#     Observations
#     1. On decreasing target update freq the varience of model increasing and on increasing convergence is taking longer
#     2. low discount factors unable to clearly differentiate the increase in steps after some treshlod
#     3. Increasing mini batch helping to achieve convergence faster
#     4.

# %%
# implementing DQN class

class DQN:

    REPLAY_MEMORY_SIZE = 8192 			# number of tuples in experience replay  
    EPSILON = 0.5 						# epsilon of epsilon-greedy exploation
    EPSILON_DECAY = 0.9999 				# exponential decay multiplier for epsilon
    HIDDEN1_SIZE = 32 					# size of hidden layer 1 --> try 16*
    HIDDEN2_SIZE = 16 					# size of hidden layer 2
    EPISODES_NUM = 2000 				# number of episodes to train on. Ideally shouldn't take longer than 2000
    MAX_STEPS = 200 					# maximum number of steps in an episode 
    LEARNING_RATE = 0.001 				# learning rate and other parameters for SGD/RMSProp/Adam --> try 0.001*, 0.003
    MINIBATCH_SIZE = 64 				# size of minibatch sampled from the experience replay --> try 16*, 8
    DISCOUNT_FACTOR = 0.999 			# MDP's gamma --> try 0.999*, 0.99
    TARGET_UPDATE_FREQ = 100 			# number of steps (not episodes) after which to update the target networks --> try 50, 20*     
    LOG_DIR = './logs' 					# directory wherein logging takes place
    EPSILON_MIN = 0.02                  # 0.05*


    # Create and initialize the environment
    def __init__(self, env):
        self.env = gym.make(env)
        assert len(self.env.observation_space.shape) == 1
        self.input_size = self.env.observation_space.shape[0]		# In case of cartpole, 4 state features
        self.output_size = self.env.action_space.n					# In case of cartpole, 2 actions (right/left)
        self.eps = self.EPSILON
        self.episodic_rewards = []
        self.episodic_steps = []

    # Create the Q-network
    def initialize_network(self):
        
        ############################################################
        # Design your q-network here.
        # 
        # Add hidden layers and the output layer. For instance:
        # 
        # with tf.name_scope('output'):
        #	W_n = tf.Variable(
        # 			 tf.truncated_normal([self.HIDDEN_n-1_SIZE, self.output_size], 
        # 			 stddev=0.01), name='W_n')
        # 	b_n = tf.Variable(tf.zeros(self.output_size), name='b_n')
        # 	self.Q = tf.matmul(h_n-1, W_n) + b_n
        #
        #############################################################
        
        # Model designed using keras layers
        self.model = keras.Sequential([
                layers.InputLayer(input_shape=(self.input_size,)),
                layers.Dense(self.HIDDEN1_SIZE, activation='relu', name='hidden1', kernel_initializer='RandomNormal'),
                layers.Dense(self.HIDDEN2_SIZE, activation='relu', name='hidden2', kernel_initializer='RandomNormal'),
                layers.Dense(self.output_size, activation='linear', name='output', kernel_initializer='RandomNormal')
        ])

        ############################################################
        # Next, compute the loss.
        #
        # First, compute the q-values. Note that you need to calculate these
        # for the actions in the (s,a,s',r) tuples from the experience replay's minibatch
        #
        # Next, compute the l2 loss between these estimated q-values and 
        # the target (which is computed using the frozen target network)
        #
        ############################################################
        
        ############################################################
        # Finally, choose a gradient descent algorithm : SGD/RMSProp/Adam. 
        #
        # For instance:
        # optimizer = tf.train.GradientDescentOptimizer(self.LEARNING_RATE)
        # global_step = tf.Variable(0, name='global_step', trainable=False)
        # self.train_op = optimizer.minimize(self.loss, global_step=global_step)
        #
        ############################################################

        # Assigned descent algo. and loss function in one line
        self.model.compile(loss=keras.losses.MeanSquaredError(),optimizer=keras.optimizers.Adam(lr=self.LEARNING_RATE))
        self.model.summary()
        
        # create a target model a clone to our model i.e. target network
#         self.target_model = keras.models.clone_model(self.model)
#         self.target_model.build((None, self.input_size))
#         self.target_model.compile(loss=keras.losses.MeanSquaredError(),optimizer=keras.optimizers.Adam(lr=self.LEARNING_RATE))
#         self.target_model.set_weights(self.model.get_weights())

        ############################################################

    def train(self, episodes_num=EPISODES_NUM):

        # Initialize summary for TensorBoard 
        summary_writer = tf.summary.create_file_writer(self.LOG_DIR)
        summary = tf.summary
        # Alternatively, you could use animated real-time plots from matplotlib 
        # (https://stackoverflow.com/a/24228275/3284912)

        ############################################################
        # Initialize other variables (like the replay memory)
        ############################################################
        
        # Using deque
        self.replay_buffer = deque(maxlen=self.REPLAY_MEMORY_SIZE)
        total_steps = 0

        ############################################################
        # Main training loop
        # 
        # In each episode, 
        #	pick the action for the given state, 
        #	perform a 'step' in the environment to get the reward and next state,
        #	update the replay buffer,
        #	sample a random minibatch from the replay buffer,
        # 	perform Q-learning,
        #	update the target network, if required.
        #
        #
        #
        # You'll need to write code in various places in the following skeleton
        #
        ############################################################

        for episode in range(episodes_num):

            state = self.env.reset()

            ############################################################
            # Episode-specific initializations go here.
            ############################################################
            
            episode_length = 0
            score = 0
            
            ############################################################

            while True:
                ############################################################
                # Pick the next action using epsilon greedy and execute it
                ############################################################
                episode_length += 1
                total_steps += 1
                if(rd.random() < self.eps):
                    act = self.env.action_space.sample()
                else:
                    act = np.argmax(self.model.predict(np.array([state]))[0])

                ############################################################
                # Step in the environment. Something like: 
                # next_state, reward, done, _ = self.env.step(action)
                ############################################################

                next_state, reward, done, _ = self.env.step(act)
                
                ############################################################
                # Update the (limited) replay buffer. 
                #
                # Note : when the replay buffer is full, you'll need to 
                # remove an entry to accommodate a new one.
                ############################################################

                # The max length in deque removes oldest if buffer size exceeds it
                x = 0
                if done:
                    x = 1
                self.replay_buffer.append(((state),act,reward,(next_state),x))
                score += reward
                state = next_state

                ############################################################
                # Sample a random minibatch and perform Q-learning (fetch max Q at s') 
                #
                # Remember, the target (r + gamma * max Q) is computed    
                # with the help of the target network.
                # Compute this target and pass it to the network for computing 
                # and minimizing the loss with the current estimates
                #
                ############################################################
                
                # not starting network update until it has a batch size elements
                if len(self.replay_buffer) >= self.REPLAY_MEMORY_SIZE: # REPLAY_MEMORY_SIZE / MINI
                    replay_batch = np.array(rd.sample(self.replay_buffer,self.MINIBATCH_SIZE))
                    nst = []
                    st = []
                    for y in replay_batch:
                        nst.append(y[3])
                        st.append(y[0])
                    max_Q = np.amax(self.model.predict(np.array(nst),workers=8, use_multiprocessing=True),1)
                    batch_targets = self.model.predict(np.array(st),workers=8, use_multiprocessing=True)
                    # for st, act, rwd, nst, d in replay_batch:
                    #     if d:
                    #         y = rwd
                    #     else:
                    #         y = (rwd + self.DISCOUNT_FACTOR * np.max(self.target_model.predict(nst)[0]))
                    #     tgt = self.model.predict(st)[0]
                    #     tgt[act] = y
                    #     batch_states.append(st[0])
                    #     batch_targets.append(tgt)
                    # print(max_Q)
                    # print(np.shape((1-replay_batch[:,4])))
                    tgts = replay_batch[:,2] + self.DISCOUNT_FACTOR * max_Q * (1-replay_batch[:,4])
                    for y in range(len(batch_targets)):
                        batch_targets[y][replay_batch[y,1]] = tgts[y]
                    self.model.fit(np.array(st), batch_targets, epochs=1, verbose = 0, workers=8, use_multiprocessing=True)
                    
                    if self.eps > self.EPSILON_MIN:
                        self.eps *= self.EPSILON_DECAY
                    elif self.eps < self.EPSILON_MIN:
                        self.eps = self.EPSILON_MIN

                ############################################################
                # Update target weights. 
                #
                # Something along the lines of:
                # if total_steps % self.TARGET_UPDATE_FREQ == 0:
                # 	target_weights = self.session.run(self.weights)
                ############################################################

#                 if total_steps%self.TARGET_UPDATE_FREQ == 0:
#                     self.target_model.set_weights(self.model.get_weights())

                ############################################################
                # Break out of the loop if the episode ends
                #
                # Something like:
                # if done or (episode_length == self.MAX_STEPS):
                # 	break
                #
                ############################################################
                
                if done or episode_length == self.MAX_STEPS:
                    self.episodic_rewards.append(score)
                    self.episodic_steps.append(episode_length)
                    break


            ############################################################
            # Logging. 
            #
            # Very important. This is what gives an idea of how good the current
            # experiment is, and if one should terminate and re-run with new parameters
            # The earlier you learn how to read and visualize experiment logs quickly,
            # the faster you'll be able to prototype and learn.
            #
            # Use any debugging information you think you need.
            # For instance :

            print("Training: Episode = %d, Length = %d, Global step = %d" % (episode, episode_length, total_steps),end=', ')
            print('Eps: '+str(self.eps))
            with summary_writer.as_default():
                summary.scalar("episode length",episode ,step=episode_length)
    
    def save_model(self, name):
        self.model.save(name)
        
    def load_model(self, name):
        self.model = keras.models.load_model(name)
#         self.target_model = keras.models.load_model(name)

    # Simple function to visually 'test' a policy
    def playPolicy(self):

        done = False
        steps = 0
        state = self.env.reset()

        # we assume the CartPole task to be solved if the pole remains upright for 200 steps
        while not done and steps < 200: 
            # self.env.render()
            action = np.argmax(self.model.predict(np.array([state]))[0])
            state, _, done, _ = self.env.step(action)
            steps += 1

        return steps

# %%
# Create and initialize the model
# dqn = DQN('CartPole-v0')
# dqn.initialize_network()

print("\nStarting training...\n")
dqn.train()
print("\nFinished training...\nCheck out some demonstrations\n")
# Out:
# Starting training...
#
# Training: Episode = 0, Length = 10, Global step = 10, Eps: 0.027979271678172192
# Training: Episode = 1, Length = 8, Global step = 18, Eps: 0.027979271678172192
# Training: Episode = 2, Length = 9, Global step = 27, Eps: 0.027979271678172192
# Training: Episode = 3, Length = 9, Global step = 36, Eps: 0.027979271678172192
# Training: Episode = 4, Length = 8, Global step = 44, Eps: 0.027979271678172192
# Training: Episode = 5, Length = 10, Global step = 54, Eps: 0.027979271678172192
# Training: Episode = 6, Length = 11, Global step = 65, Eps: 0.027979271678172192
# Training: Episode = 7, Length = 9, Global step = 74, Eps: 0.027979271678172192
# Training: Episode = 8, Length = 9, Global step = 83, Eps: 0.027979271678172192
# Training: Episode = 9, Length = 12, Global step = 95, Eps: 0.027979271678172192
# Training: Episode = 10, Length = 9, Global step = 104, Eps: 0.027979271678172192
# Training: Episode = 11, Length = 8, Global step = 112, Eps: 0.027979271678172192
# Training: Episode = 12, Length = 9, Global step = 121, Eps: 0.027979271678172192
# Training: Episode = 13, Length = 10, Global step = 131, Eps: 0.027979271678172192
# Training: Episode = 14, Length = 8, Global step = 139, Eps: 0.027979271678172192
# Training: Episode = 15, Length = 10, Global step = 149, Eps: 0.027979271678172192
# Training: Episode = 16, Length = 9, Global step = 158, Eps: 0.027979271678172192
# Training: Episode = 17, Length = 10, Global step = 168, Eps: 0.027979271678172192
# Training: Episode = 18, Length = 9, Global step = 177, Eps: 0.027979271678172192
# Training: Episode = 19, Length = 8, Global step = 185, Eps: 0.027979271678172192
# Training: Episode = 20, Length = 10, Global step = 195, Eps: 0.027979271678172192
# Training: Episode = 21, Length = 10, Global step = 205, Eps: 0.027979271678172192
# Training: Episode = 22, Length = 10, Global step = 215, Eps: 0.027979271678172192
# Training: Episode = 23, Length = 9, Global step = 224, Eps: 0.027979271678172192
# Training: Episode = 24, Length = 9, Global step = 233, Eps: 0.027979271678172192
# Training: Episode = 25, Length = 11, Global step = 244, Eps: 0.027979271678172192
# Training: Episode = 26, Length = 10, Global step = 254, Eps: 0.027979271678172192
# Training: Episode = 27, Length = 9, Global step = 263, Eps: 0.027979271678172192
# Training: Episode = 28, Length = 10, Global step = 273, Eps: 0.027979271678172192
# Training: Episode = 29, Length = 9, Global step = 282, Eps: 0.027979271678172192
# Training: Episode = 30, Length = 10, Global step = 292, Eps: 0.027979271678172192
# Training: Episode = 31, Length = 10, Global step = 302, Eps: 0.027979271678172192
# Training: Episode = 32, Length = 10, Global step = 312, Eps: 0.027979271678172192
# Training: Episode = 33, Length = 9, Global step = 321, Eps: 0.027979271678172192
# Training: Episode = 34, Length = 10, Global step = 331, Eps: 0.027979271678172192
# Training: Episode = 35, Length = 9, Global step = 340, Eps: 0.027979271678172192
# Training: Episode = 36, Length = 10, Global step = 350, Eps: 0.027979271678172192
# Training: Episode = 37, Length = 9, Global step = 359, Eps: 0.027979271678172192
# Training: Episode = 38, Length = 9, Global step = 368, Eps: 0.027979271678172192
# Training: Episode = 39, Length = 11, Global step = 379, Eps: 0.027979271678172192
# Training: Episode = 40, Length = 10, Global step = 389, Eps: 0.027979271678172192
# Training: Episode = 41, Length = 11, Global step = 400, Eps: 0.027979271678172192
# Training: Episode = 42, Length = 8, Global step = 408, Eps: 0.027979271678172192
# Training: Episode = 43, Length = 10, Global step = 418, Eps: 0.027979271678172192
# Training: Episode = 44, Length = 9, Global step = 427, Eps: 0.027979271678172192
# Training: Episode = 45, Length = 8, Global step = 435, Eps: 0.027979271678172192
# Training: Episode = 46, Length = 11, Global step = 446, Eps: 0.027979271678172192
# Training: Episode = 47, Length = 12, Global step = 458, Eps: 0.027979271678172192
# Training: Episode = 48, Length = 10, Global step = 468, Eps: 0.027979271678172192
# Training: Episode = 49, Length = 9, Global step = 477, Eps: 0.027979271678172192
# Training: Episode = 50, Length = 10, Global step = 487, Eps: 0.027979271678172192
# Training: Episode = 51, Length = 8, Global step = 495, Eps: 0.027979271678172192
# Training: Episode = 52, Length = 11, Global step = 506, Eps: 0.027979271678172192
# Training: Episode = 53, Length = 10, Global step = 516, Eps: 0.027979271678172192
# Training: Episode = 54, Length = 9, Global step = 525, Eps: 0.027979271678172192
# Training: Episode = 55, Length = 9, Global step = 534, Eps: 0.027979271678172192
# Training: Episode = 56, Length = 9, Global step = 543, Eps: 0.027979271678172192
# Training: Episode = 57, Length = 10, Global step = 553, Eps: 0.027979271678172192
# Training: Episode = 58, Length = 9, Global step = 562, Eps: 0.027979271678172192
# Training: Episode = 59, Length = 11, Global step = 573, Eps: 0.027979271678172192
# Training: Episode = 60, Length = 11, Global step = 584, Eps: 0.027979271678172192
# Training: Episode = 61, Length = 11, Global step = 595, Eps: 0.027979271678172192
# Training: Episode = 62, Length = 9, Global step = 604, Eps: 0.027979271678172192
# Training: Episode = 63, Length = 10, Global step = 614, Eps: 0.027979271678172192
# Training: Episode = 64, Length = 9, Global step = 623, Eps: 0.027979271678172192
# Training: Episode = 65, Length = 12, Global step = 635, Eps: 0.027979271678172192
# Training: Episode = 66, Length = 9, Global step = 644, Eps: 0.027979271678172192
# Training: Episode = 67, Length = 9, Global step = 653, Eps: 0.027979271678172192
# Training: Episode = 68, Length = 9, Global step = 662, Eps: 0.027979271678172192
# Training: Episode = 69, Length = 9, Global step = 671, Eps: 0.027979271678172192
# Training: Episode = 70, Length = 9, Global step = 680, Eps: 0.027979271678172192
# Training: Episode = 71, Length = 9, Global step = 689, Eps: 0.027979271678172192
# Training: Episode = 72, Length = 9, Global step = 698, Eps: 0.027979271678172192
# Training: Episode = 73, Length = 9, Global step = 707, Eps: 0.027979271678172192
# Training: Episode = 74, Length = 8, Global step = 715, Eps: 0.027979271678172192
# Training: Episode = 75, Length = 9, Global step = 724, Eps: 0.027979271678172192
# Training: Episode = 76, Length = 10, Global step = 734, Eps: 0.027979271678172192
# Training: Episode = 77, Length = 8, Global step = 742, Eps: 0.027979271678172192
# Training: Episode = 78, Length = 9, Global step = 751, Eps: 0.027979271678172192
# Training: Episode = 79, Length = 10, Global step = 761, Eps: 0.027979271678172192
# Training: Episode = 80, Length = 8, Global step = 769, Eps: 0.027979271678172192
# Training: Episode = 81, Length = 10, Global step = 779, Eps: 0.027979271678172192
# Training: Episode = 82, Length = 8, Global step = 787, Eps: 0.027979271678172192
# Training: Episode = 83, Length = 8, Global step = 795, Eps: 0.027979271678172192
# Training: Episode = 84, Length = 11, Global step = 806, Eps: 0.027979271678172192
# Training: Episode = 85, Length = 10, Global step = 816, Eps: 0.027979271678172192
# Training: Episode = 86, Length = 9, Global step = 825, Eps: 0.027979271678172192
# Training: Episode = 87, Length = 8, Global step = 833, Eps: 0.027979271678172192
# Training: Episode = 88, Length = 10, Global step = 843, Eps: 0.027979271678172192
# Training: Episode = 89, Length = 8, Global step = 851, Eps: 0.027979271678172192
# Training: Episode = 90, Length = 13, Global step = 864, Eps: 0.027979271678172192
# Training: Episode = 91, Length = 10, Global step = 874, Eps: 0.027979271678172192
# Training: Episode = 92, Length = 9, Global step = 883, Eps: 0.027979271678172192
# Training: Episode = 93, Length = 10, Global step = 893, Eps: 0.027979271678172192
# Training: Episode = 94, Length = 10, Global step = 903, Eps: 0.027979271678172192
# Training: Episode = 95, Length = 8, Global step = 911, Eps: 0.027979271678172192
# Training: Episode = 96, Length = 9, Global step = 920, Eps: 0.027979271678172192
# Training: Episode = 97, Length = 10, Global step = 930, Eps: 0.027979271678172192
# Training: Episode = 98, Length = 9, Global step = 939, Eps: 0.027979271678172192
# Training: Episode = 99, Length = 8, Global step = 947, Eps: 0.027979271678172192
# Training: Episode = 100, Length = 10, Global step = 957, Eps: 0.027979271678172192
# Training: Episode = 101, Length = 10, Global step = 967, Eps: 0.027979271678172192
# Training: Episode = 102, Length = 9, Global step = 976, Eps: 0.027979271678172192
# Training: Episode = 103, Length = 10, Global step = 986, Eps: 0.027979271678172192
# Training: Episode = 104, Length = 9, Global step = 995, Eps: 0.027979271678172192
# Training: Episode = 105, Length = 8, Global step = 1003, Eps: 0.027979271678172192
# Training: Episode = 106, Length = 9, Global step = 1012, Eps: 0.027979271678172192
# Training: Episode = 107, Length = 10, Global step = 1022, Eps: 0.027979271678172192
# Training: Episode = 108, Length = 8, Global step = 1030, Eps: 0.027979271678172192
# Training: Episode = 109, Length = 8, Global step = 1038, Eps: 0.027979271678172192
# Training: Episode = 110, Length = 8, Global step = 1046, Eps: 0.027979271678172192
# Training: Episode = 111, Length = 9, Global step = 1055, Eps: 0.027979271678172192
# Training: Episode = 112, Length = 10, Global step = 1065, Eps: 0.027979271678172192
# Training: Episode = 113, Length = 8, Global step = 1073, Eps: 0.027979271678172192
# Training: Episode = 114, Length = 9, Global step = 1082, Eps: 0.027979271678172192
# Training: Episode = 115, Length = 10, Global step = 1092, Eps: 0.027979271678172192
# Training: Episode = 116, Length = 10, Global step = 1102, Eps: 0.027979271678172192
# Training: Episode = 117, Length = 8, Global step = 1110, Eps: 0.027979271678172192
# Training: Episode = 118, Length = 11, Global step = 1121, Eps: 0.027979271678172192
# Training: Episode = 119, Length = 8, Global step = 1129, Eps: 0.027979271678172192
# Training: Episode = 120, Length = 9, Global step = 1138, Eps: 0.027979271678172192
# Training: Episode = 121, Length = 8, Global step = 1146, Eps: 0.027979271678172192
# Training: Episode = 122, Length = 11, Global step = 1157, Eps: 0.027979271678172192
# Training: Episode = 123, Length = 10, Global step = 1167, Eps: 0.027979271678172192
# Training: Episode = 124, Length = 9, Global step = 1176, Eps: 0.027979271678172192
# Training: Episode = 125, Length = 9, Global step = 1185, Eps: 0.027979271678172192
# Training: Episode = 126, Length = 9, Global step = 1194, Eps: 0.027979271678172192
# Training: Episode = 127, Length = 10, Global step = 1204, Eps: 0.027979271678172192
# Training: Episode = 128, Length = 9, Global step = 1213, Eps: 0.027979271678172192
# Training: Episode = 129, Length = 9, Global step = 1222, Eps: 0.027979271678172192
# Training: Episode = 130, Length = 9, Global step = 1231, Eps: 0.027979271678172192
# Training: Episode = 131, Length = 8, Global step = 1239, Eps: 0.027979271678172192
# Training: Episode = 132, Length = 11, Global step = 1250, Eps: 0.027979271678172192
# Training: Episode = 133, Length = 9, Global step = 1259, Eps: 0.027979271678172192
# Training: Episode = 134, Length = 9, Global step = 1268, Eps: 0.027979271678172192
# Training: Episode = 135, Length = 9, Global step = 1277, Eps: 0.027979271678172192
# Training: Episode = 136, Length = 11, Global step = 1288, Eps: 0.027979271678172192
# Training: Episode = 137, Length = 9, Global step = 1297, Eps: 0.027979271678172192
# Training: Episode = 138, Length = 9, Global step = 1306, Eps: 0.027979271678172192
# Training: Episode = 139, Length = 10, Global step = 1316, Eps: 0.027979271678172192
# Training: Episode = 140, Length = 10, Global step = 1326, Eps: 0.027979271678172192
# Training: Episode = 141, Length = 9, Global step = 1335, Eps: 0.027979271678172192
# Training: Episode = 142, Length = 9, Global step = 1344, Eps: 0.027979271678172192
# Training: Episode = 143, Length = 9, Global step = 1353, Eps: 0.027979271678172192
# Training: Episode = 144, Length = 11, Global step = 1364, Eps: 0.027979271678172192
# Training: Episode = 145, Length = 9, Global step = 1373, Eps: 0.027979271678172192
# Training: Episode = 146, Length = 9, Global step = 1382, Eps: 0.027979271678172192
# Training: Episode = 147, Length = 8, Global step = 1390, Eps: 0.027979271678172192
# Training: Episode = 148, Length = 9, Global step = 1399, Eps: 0.027979271678172192
# Training: Episode = 149, Length = 9, Global step = 1408, Eps: 0.027979271678172192
# Training: Episode = 150, Length = 9, Global step = 1417, Eps: 0.027979271678172192
# Training: Episode = 151, Length = 9, Global step = 1426, Eps: 0.027979271678172192
# Training: Episode = 152, Length = 9, Global step = 1435, Eps: 0.027979271678172192
# Training: Episode = 153, Length = 9, Global step = 1444, Eps: 0.027979271678172192
# Training: Episode = 154, Length = 10, Global step = 1454, Eps: 0.027979271678172192
# Training: Episode = 155, Length = 10, Global step = 1464, Eps: 0.027979271678172192
# Training: Episode = 156, Length = 10, Global step = 1474, Eps: 0.027979271678172192
# Training: Episode = 157, Length = 10, Global step = 1484, Eps: 0.027979271678172192
# Training: Episode = 158, Length = 15, Global step = 1499, Eps: 0.027979271678172192
# Training: Episode = 159, Length = 9, Global step = 1508, Eps: 0.027979271678172192
# Training: Episode = 160, Length = 10, Global step = 1518, Eps: 0.027979271678172192
# Training: Episode = 161, Length = 10, Global step = 1528, Eps: 0.027979271678172192
# Training: Episode = 162, Length = 10, Global step = 1538, Eps: 0.027979271678172192
# Training: Episode = 163, Length = 8, Global step = 1546, Eps: 0.027979271678172192
# Training: Episode = 164, Length = 9, Global step = 1555, Eps: 0.027979271678172192
# Training: Episode = 165, Length = 10, Global step = 1565, Eps: 0.027979271678172192
# Training: Episode = 166, Length = 10, Global step = 1575, Eps: 0.027979271678172192
# Training: Episode = 167, Length = 9, Global step = 1584, Eps: 0.027979271678172192
# Training: Episode = 168, Length = 10, Global step = 1594, Eps: 0.027979271678172192
# Training: Episode = 169, Length = 11, Global step = 1605, Eps: 0.027979271678172192
# Training: Episode = 170, Length = 10, Global step = 1615, Eps: 0.027979271678172192
# Training: Episode = 171, Length = 9, Global step = 1624, Eps: 0.027979271678172192
# Training: Episode = 172, Length = 10, Global step = 1634, Eps: 0.027979271678172192
# Training: Episode = 173, Length = 11, Global step = 1645, Eps: 0.027979271678172192
# Training: Episode = 174, Length = 9, Global step = 1654, Eps: 0.027979271678172192
# Training: Episode = 175, Length = 9, Global step = 1663, Eps: 0.027979271678172192
# Training: Episode = 176, Length = 10, Global step = 1673, Eps: 0.027979271678172192
# Training: Episode = 177, Length = 9, Global step = 1682, Eps: 0.027979271678172192
# Training: Episode = 178, Length = 9, Global step = 1691, Eps: 0.027979271678172192
# Training: Episode = 179, Length = 9, Global step = 1700, Eps: 0.027979271678172192
# Training: Episode = 180, Length = 13, Global step = 1713, Eps: 0.027979271678172192
# Training: Episode = 181, Length = 9, Global step = 1722, Eps: 0.027979271678172192
# Training: Episode = 182, Length = 10, Global step = 1732, Eps: 0.027979271678172192
# Training: Episode = 183, Length = 9, Global step = 1741, Eps: 0.027979271678172192
# Training: Episode = 184, Length = 11, Global step = 1752, Eps: 0.027979271678172192
# Training: Episode = 185, Length = 9, Global step = 1761, Eps: 0.027979271678172192
# Training: Episode = 186, Length = 9, Global step = 1770, Eps: 0.027979271678172192
# Training: Episode = 187, Length = 10, Global step = 1780, Eps: 0.027979271678172192
# Training: Episode = 188, Length = 10, Global step = 1790, Eps: 0.027979271678172192
# Training: Episode = 189, Length = 9, Global step = 1799, Eps: 0.027979271678172192
# Training: Episode = 190, Length = 9, Global step = 1808, Eps: 0.027979271678172192
# Training: Episode = 191, Length = 10, Global step = 1818, Eps: 0.027979271678172192
# Training: Episode = 192, Length = 10, Global step = 1828, Eps: 0.027979271678172192
# Training: Episode = 193, Length = 10, Global step = 1838, Eps: 0.027979271678172192
# Training: Episode = 194, Length = 9, Global step = 1847, Eps: 0.027979271678172192
# Training: Episode = 195, Length = 10, Global step = 1857, Eps: 0.027979271678172192
# Training: Episode = 196, Length = 9, Global step = 1866, Eps: 0.027979271678172192
# Training: Episode = 197, Length = 9, Global step = 1875, Eps: 0.027979271678172192
# Training: Episode = 198, Length = 10, Global step = 1885, Eps: 0.027979271678172192
# Training: Episode = 199, Length = 9, Global step = 1894, Eps: 0.027979271678172192
# Training: Episode = 200, Length = 9, Global step = 1903, Eps: 0.027979271678172192
# Training: Episode = 201, Length = 9, Global step = 1912, Eps: 0.027979271678172192
# Training: Episode = 202, Length = 9, Global step = 1921, Eps: 0.027979271678172192
# Training: Episode = 203, Length = 8, Global step = 1929, Eps: 0.027979271678172192
# Training: Episode = 204, Length = 9, Global step = 1938, Eps: 0.027979271678172192
# Training: Episode = 205, Length = 9, Global step = 1947, Eps: 0.027979271678172192
# Training: Episode = 206, Length = 11, Global step = 1958, Eps: 0.027979271678172192
# Training: Episode = 207, Length = 8, Global step = 1966, Eps: 0.027979271678172192
# Training: Episode = 208, Length = 9, Global step = 1975, Eps: 0.027979271678172192
# Training: Episode = 209, Length = 10, Global step = 1985, Eps: 0.027979271678172192
# Training: Episode = 210, Length = 9, Global step = 1994, Eps: 0.027979271678172192
# Training: Episode = 211, Length = 9, Global step = 2003, Eps: 0.027979271678172192
# Training: Episode = 212, Length = 9, Global step = 2012, Eps: 0.027979271678172192
# Training: Episode = 213, Length = 10, Global step = 2022, Eps: 0.027979271678172192
# Training: Episode = 214, Length = 10, Global step = 2032, Eps: 0.027979271678172192
# Training: Episode = 215, Length = 10, Global step = 2042, Eps: 0.027979271678172192
# Training: Episode = 216, Length = 9, Global step = 2051, Eps: 0.027979271678172192
# Training: Episode = 217, Length = 9, Global step = 2060, Eps: 0.027979271678172192
# Training: Episode = 218, Length = 9, Global step = 2069, Eps: 0.027979271678172192
# Training: Episode = 219, Length = 10, Global step = 2079, Eps: 0.027979271678172192
# Training: Episode = 220, Length = 9, Global step = 2088, Eps: 0.027979271678172192
# Training: Episode = 221, Length = 10, Global step = 2098, Eps: 0.027979271678172192
# Training: Episode = 222, Length = 8, Global step = 2106, Eps: 0.027979271678172192
# Training: Episode = 223, Length = 9, Global step = 2115, Eps: 0.027979271678172192
# Training: Episode = 224, Length = 11, Global step = 2126, Eps: 0.027979271678172192
# Training: Episode = 225, Length = 9, Global step = 2135, Eps: 0.027979271678172192
# Training: Episode = 226, Length = 9, Global step = 2144, Eps: 0.027979271678172192
# Training: Episode = 227, Length = 9, Global step = 2153, Eps: 0.027979271678172192
# Training: Episode = 228, Length = 8, Global step = 2161, Eps: 0.027979271678172192
# Training: Episode = 229, Length = 10, Global step = 2171, Eps: 0.027979271678172192
# Training: Episode = 230, Length = 10, Global step = 2181, Eps: 0.027979271678172192
# Training: Episode = 231, Length = 9, Global step = 2190, Eps: 0.027979271678172192
# Training: Episode = 232, Length = 9, Global step = 2199, Eps: 0.027979271678172192
# Training: Episode = 233, Length = 10, Global step = 2209, Eps: 0.027979271678172192
# Training: Episode = 234, Length = 9, Global step = 2218, Eps: 0.027979271678172192
# Training: Episode = 235, Length = 9, Global step = 2227, Eps: 0.027979271678172192
# Training: Episode = 236, Length = 10, Global step = 2237, Eps: 0.027979271678172192
# Training: Episode = 237, Length = 8, Global step = 2245, Eps: 0.027979271678172192
# Training: Episode = 238, Length = 8, Global step = 2253, Eps: 0.027979271678172192
# Training: Episode = 239, Length = 8, Global step = 2261, Eps: 0.027979271678172192
# Training: Episode = 240, Length = 8, Global step = 2269, Eps: 0.027979271678172192
# Training: Episode = 241, Length = 11, Global step = 2280, Eps: 0.027979271678172192
# Training: Episode = 242, Length = 10, Global step = 2290, Eps: 0.027979271678172192
# Training: Episode = 243, Length = 11, Global step = 2301, Eps: 0.027979271678172192
# Training: Episode = 244, Length = 10, Global step = 2311, Eps: 0.027979271678172192
# Training: Episode = 245, Length = 9, Global step = 2320, Eps: 0.027979271678172192
# Training: Episode = 246, Length = 8, Global step = 2328, Eps: 0.027979271678172192
# Training: Episode = 247, Length = 8, Global step = 2336, Eps: 0.027979271678172192
# Training: Episode = 248, Length = 10, Global step = 2346, Eps: 0.027979271678172192
# Training: Episode = 249, Length = 10, Global step = 2356, Eps: 0.027979271678172192
# Training: Episode = 250, Length = 9, Global step = 2365, Eps: 0.027979271678172192
# Training: Episode = 251, Length = 9, Global step = 2374, Eps: 0.027979271678172192
# Training: Episode = 252, Length = 10, Global step = 2384, Eps: 0.027979271678172192
# Training: Episode = 253, Length = 9, Global step = 2393, Eps: 0.027979271678172192
# Training: Episode = 254, Length = 10, Global step = 2403, Eps: 0.027979271678172192
# Training: Episode = 255, Length = 8, Global step = 2411, Eps: 0.027979271678172192
# Training: Episode = 256, Length = 8, Global step = 2419, Eps: 0.027979271678172192
# Training: Episode = 257, Length = 9, Global step = 2428, Eps: 0.027979271678172192
# Training: Episode = 258, Length = 11, Global step = 2439, Eps: 0.027979271678172192
# Training: Episode = 259, Length = 10, Global step = 2449, Eps: 0.027979271678172192
# Training: Episode = 260, Length = 11, Global step = 2460, Eps: 0.027979271678172192
# Training: Episode = 261, Length = 9, Global step = 2469, Eps: 0.027979271678172192
# Training: Episode = 262, Length = 9, Global step = 2478, Eps: 0.027979271678172192
# Training: Episode = 263, Length = 10, Global step = 2488, Eps: 0.027979271678172192
# Training: Episode = 264, Length = 9, Global step = 2497, Eps: 0.027979271678172192
# Training: Episode = 265, Length = 8, Global step = 2505, Eps: 0.027979271678172192
# Training: Episode = 266, Length = 9, Global step = 2514, Eps: 0.027979271678172192
# Training: Episode = 267, Length = 10, Global step = 2524, Eps: 0.027979271678172192
# Training: Episode = 268, Length = 10, Global step = 2534, Eps: 0.027979271678172192
# Training: Episode = 269, Length = 10, Global step = 2544, Eps: 0.027979271678172192
# Training: Episode = 270, Length = 10, Global step = 2554, Eps: 0.027979271678172192
# Training: Episode = 271, Length = 11, Global step = 2565, Eps: 0.027979271678172192
# Training: Episode = 272, Length = 10, Global step = 2575, Eps: 0.027979271678172192
# Training: Episode = 273, Length = 10, Global step = 2585, Eps: 0.027979271678172192
# Training: Episode = 274, Length = 10, Global step = 2595, Eps: 0.027979271678172192
# Training: Episode = 275, Length = 10, Global step = 2605, Eps: 0.027979271678172192
# Training: Episode = 276, Length = 10, Global step = 2615, Eps: 0.027979271678172192
# Training: Episode = 277, Length = 9, Global step = 2624, Eps: 0.027979271678172192
# Training: Episode = 278, Length = 10, Global step = 2634, Eps: 0.027979271678172192
# Training: Episode = 279, Length = 10, Global step = 2644, Eps: 0.027979271678172192
# Training: Episode = 280, Length = 9, Global step = 2653, Eps: 0.027979271678172192
# Training: Episode = 281, Length = 8, Global step = 2661, Eps: 0.027979271678172192
# Training: Episode = 282, Length = 10, Global step = 2671, Eps: 0.027979271678172192
# Training: Episode = 283, Length = 9, Global step = 2680, Eps: 0.027979271678172192
# Training: Episode = 284, Length = 10, Global step = 2690, Eps: 0.027979271678172192
# Training: Episode = 285, Length = 10, Global step = 2700, Eps: 0.027979271678172192
# Training: Episode = 286, Length = 9, Global step = 2709, Eps: 0.027979271678172192
# Training: Episode = 287, Length = 10, Global step = 2719, Eps: 0.027979271678172192
# Training: Episode = 288, Length = 9, Global step = 2728, Eps: 0.027979271678172192
# Training: Episode = 289, Length = 10, Global step = 2738, Eps: 0.027979271678172192
# Training: Episode = 290, Length = 10, Global step = 2748, Eps: 0.027979271678172192
# Training: Episode = 291, Length = 9, Global step = 2757, Eps: 0.027979271678172192
# Training: Episode = 292, Length = 9, Global step = 2766, Eps: 0.027979271678172192
# Training: Episode = 293, Length = 9, Global step = 2775, Eps: 0.027979271678172192
# Training: Episode = 294, Length = 9, Global step = 2784, Eps: 0.027979271678172192
# Training: Episode = 295, Length = 10, Global step = 2794, Eps: 0.027979271678172192
# Training: Episode = 296, Length = 8, Global step = 2802, Eps: 0.027979271678172192
# Training: Episode = 297, Length = 10, Global step = 2812, Eps: 0.027979271678172192
# Training: Episode = 298, Length = 11, Global step = 2823, Eps: 0.027979271678172192
# Training: Episode = 299, Length = 13, Global step = 2836, Eps: 0.027979271678172192
# Training: Episode = 300, Length = 10, Global step = 2846, Eps: 0.027979271678172192
# Training: Episode = 301, Length = 9, Global step = 2855, Eps: 0.027979271678172192
# Training: Episode = 302, Length = 9, Global step = 2864, Eps: 0.027979271678172192
# Training: Episode = 303, Length = 9, Global step = 2873, Eps: 0.027979271678172192
# Training: Episode = 304, Length = 10, Global step = 2883, Eps: 0.027979271678172192
# Training: Episode = 305, Length = 9, Global step = 2892, Eps: 0.027979271678172192
# Training: Episode = 306, Length = 9, Global step = 2901, Eps: 0.027979271678172192
# Training: Episode = 307, Length = 9, Global step = 2910, Eps: 0.027979271678172192
# Training: Episode = 308, Length = 9, Global step = 2919, Eps: 0.027979271678172192
# Training: Episode = 309, Length = 10, Global step = 2929, Eps: 0.027979271678172192
# Training: Episode = 310, Length = 10, Global step = 2939, Eps: 0.027979271678172192
# Training: Episode = 311, Length = 9, Global step = 2948, Eps: 0.027979271678172192
# Training: Episode = 312, Length = 9, Global step = 2957, Eps: 0.027979271678172192
# Training: Episode = 313, Length = 10, Global step = 2967, Eps: 0.027979271678172192
# Training: Episode = 314, Length = 8, Global step = 2975, Eps: 0.027979271678172192
# Training: Episode = 315, Length = 11, Global step = 2986, Eps: 0.027979271678172192
# Training: Episode = 316, Length = 8, Global step = 2994, Eps: 0.027979271678172192
# Training: Episode = 317, Length = 9, Global step = 3003, Eps: 0.027979271678172192
# Training: Episode = 318, Length = 10, Global step = 3013, Eps: 0.027979271678172192
# Training: Episode = 319, Length = 10, Global step = 3023, Eps: 0.027979271678172192
# Training: Episode = 320, Length = 10, Global step = 3033, Eps: 0.027979271678172192
# Training: Episode = 321, Length = 9, Global step = 3042, Eps: 0.027979271678172192
# Training: Episode = 322, Length = 10, Global step = 3052, Eps: 0.027979271678172192
# Training: Episode = 323, Length = 9, Global step = 3061, Eps: 0.027979271678172192
# Training: Episode = 324, Length = 10, Global step = 3071, Eps: 0.027979271678172192
# Training: Episode = 325, Length = 11, Global step = 3082, Eps: 0.027979271678172192
# Training: Episode = 326, Length = 9, Global step = 3091, Eps: 0.027979271678172192
# Training: Episode = 327, Length = 10, Global step = 3101, Eps: 0.027979271678172192
# Training: Episode = 328, Length = 9, Global step = 3110, Eps: 0.027979271678172192
# Training: Episode = 329, Length = 10, Global step = 3120, Eps: 0.027979271678172192
# Training: Episode = 330, Length = 9, Global step = 3129, Eps: 0.027979271678172192
# Training: Episode = 331, Length = 9, Global step = 3138, Eps: 0.027979271678172192
# Training: Episode = 332, Length = 8, Global step = 3146, Eps: 0.027979271678172192
# Training: Episode = 333, Length = 10, Global step = 3156, Eps: 0.027979271678172192
# Training: Episode = 334, Length = 9, Global step = 3165, Eps: 0.027979271678172192
# Training: Episode = 335, Length = 10, Global step = 3175, Eps: 0.027979271678172192
# Training: Episode = 336, Length = 9, Global step = 3184, Eps: 0.027979271678172192
# Training: Episode = 337, Length = 10, Global step = 3194, Eps: 0.027979271678172192
# Training: Episode = 338, Length = 10, Global step = 3204, Eps: 0.027979271678172192
# Training: Episode = 339, Length = 9, Global step = 3213, Eps: 0.027979271678172192
# Training: Episode = 340, Length = 10, Global step = 3223, Eps: 0.027979271678172192
# Training: Episode = 341, Length = 10, Global step = 3233, Eps: 0.027979271678172192
# Training: Episode = 342, Length = 10, Global step = 3243, Eps: 0.027979271678172192
# Training: Episode = 343, Length = 9, Global step = 3252, Eps: 0.027979271678172192
# Training: Episode = 344, Length = 9, Global step = 3261, Eps: 0.027979271678172192
# Training: Episode = 345, Length = 10, Global step = 3271, Eps: 0.027979271678172192
# Training: Episode = 346, Length = 10, Global step = 3281, Eps: 0.027979271678172192
# Training: Episode = 347, Length = 8, Global step = 3289, Eps: 0.027979271678172192
# Training: Episode = 348, Length = 9, Global step = 3298, Eps: 0.027979271678172192
# Training: Episode = 349, Length = 12, Global step = 3310, Eps: 0.027979271678172192
# Training: Episode = 350, Length = 10, Global step = 3320, Eps: 0.027979271678172192
# Training: Episode = 351, Length = 10, Global step = 3330, Eps: 0.027979271678172192
# Training: Episode = 352, Length = 11, Global step = 3341, Eps: 0.027979271678172192
# Training: Episode = 353, Length = 10, Global step = 3351, Eps: 0.027979271678172192
# Training: Episode = 354, Length = 11, Global step = 3362, Eps: 0.027979271678172192
# Training: Episode = 355, Length = 9, Global step = 3371, Eps: 0.027979271678172192
# Training: Episode = 356, Length = 8, Global step = 3379, Eps: 0.027979271678172192
# Training: Episode = 357, Length = 10, Global step = 3389, Eps: 0.027979271678172192
# Training: Episode = 358, Length = 9, Global step = 3398, Eps: 0.027979271678172192
# Training: Episode = 359, Length = 9, Global step = 3407, Eps: 0.027979271678172192
# Training: Episode = 360, Length = 9, Global step = 3416, Eps: 0.027979271678172192
# Training: Episode = 361, Length = 8, Global step = 3424, Eps: 0.027979271678172192
# Training: Episode = 362, Length = 10, Global step = 3434, Eps: 0.027979271678172192
# Training: Episode = 363, Length = 9, Global step = 3443, Eps: 0.027979271678172192
# Training: Episode = 364, Length = 8, Global step = 3451, Eps: 0.027979271678172192
# Training: Episode = 365, Length = 9, Global step = 3460, Eps: 0.027979271678172192
# Training: Episode = 366, Length = 9, Global step = 3469, Eps: 0.027979271678172192
# Training: Episode = 367, Length = 10, Global step = 3479, Eps: 0.027979271678172192
# Training: Episode = 368, Length = 9, Global step = 3488, Eps: 0.027979271678172192
# Training: Episode = 369, Length = 10, Global step = 3498, Eps: 0.027979271678172192
# Training: Episode = 370, Length = 9, Global step = 3507, Eps: 0.027979271678172192
# Training: Episode = 371, Length = 10, Global step = 3517, Eps: 0.027979271678172192
# Training: Episode = 372, Length = 9, Global step = 3526, Eps: 0.027979271678172192
# Training: Episode = 373, Length = 10, Global step = 3536, Eps: 0.027979271678172192
# Training: Episode = 374, Length = 10, Global step = 3546, Eps: 0.027979271678172192
# Training: Episode = 375, Length = 9, Global step = 3555, Eps: 0.027979271678172192
# Training: Episode = 376, Length = 10, Global step = 3565, Eps: 0.027979271678172192
# Training: Episode = 377, Length = 12, Global step = 3577, Eps: 0.027979271678172192
# Training: Episode = 378, Length = 9, Global step = 3586, Eps: 0.027979271678172192
# Training: Episode = 379, Length = 10, Global step = 3596, Eps: 0.027979271678172192
# Training: Episode = 380, Length = 9, Global step = 3605, Eps: 0.027979271678172192
# Training: Episode = 381, Length = 9, Global step = 3614, Eps: 0.027979271678172192
# Training: Episode = 382, Length = 9, Global step = 3623, Eps: 0.027979271678172192
# Training: Episode = 383, Length = 9, Global step = 3632, Eps: 0.027979271678172192
# Training: Episode = 384, Length = 11, Global step = 3643, Eps: 0.027979271678172192
# Training: Episode = 385, Length = 8, Global step = 3651, Eps: 0.027979271678172192
# Training: Episode = 386, Length = 10, Global step = 3661, Eps: 0.027979271678172192
# Training: Episode = 387, Length = 10, Global step = 3671, Eps: 0.027979271678172192
# Training: Episode = 388, Length = 9, Global step = 3680, Eps: 0.027979271678172192
# Training: Episode = 389, Length = 11, Global step = 3691, Eps: 0.027979271678172192
# Training: Episode = 390, Length = 8, Global step = 3699, Eps: 0.027979271678172192
# Training: Episode = 391, Length = 10, Global step = 3709, Eps: 0.027979271678172192
# Training: Episode = 392, Length = 8, Global step = 3717, Eps: 0.027979271678172192
# Training: Episode = 393, Length = 10, Global step = 3727, Eps: 0.027979271678172192
# Training: Episode = 394, Length = 8, Global step = 3735, Eps: 0.027979271678172192
# Training: Episode = 395, Length = 9, Global step = 3744, Eps: 0.027979271678172192
# Training: Episode = 396, Length = 10, Global step = 3754, Eps: 0.027979271678172192
# Training: Episode = 397, Length = 11, Global step = 3765, Eps: 0.027979271678172192
# Training: Episode = 398, Length = 9, Global step = 3774, Eps: 0.027979271678172192
# Training: Episode = 399, Length = 8, Global step = 3782, Eps: 0.027979271678172192
# Training: Episode = 400, Length = 8, Global step = 3790, Eps: 0.027979271678172192
# Training: Episode = 401, Length = 10, Global step = 3800, Eps: 0.027979271678172192
# Training: Episode = 402, Length = 10, Global step = 3810, Eps: 0.027979271678172192
# Training: Episode = 403, Length = 10, Global step = 3820, Eps: 0.027979271678172192
# Training: Episode = 404, Length = 10, Global step = 3830, Eps: 0.027979271678172192
# Training: Episode = 405, Length = 9, Global step = 3839, Eps: 0.027979271678172192
# Training: Episode = 406, Length = 10, Global step = 3849, Eps: 0.027979271678172192
# Training: Episode = 407, Length = 9, Global step = 3858, Eps: 0.027979271678172192
# Training: Episode = 408, Length = 10, Global step = 3868, Eps: 0.027979271678172192
# Training: Episode = 409, Length = 8, Global step = 3876, Eps: 0.027979271678172192
# Training: Episode = 410, Length = 12, Global step = 3888, Eps: 0.027979271678172192
# Training: Episode = 411, Length = 10, Global step = 3898, Eps: 0.027979271678172192
# Training: Episode = 412, Length = 9, Global step = 3907, Eps: 0.027979271678172192
# Training: Episode = 413, Length = 9, Global step = 3916, Eps: 0.027979271678172192
# Training: Episode = 414, Length = 8, Global step = 3924, Eps: 0.027979271678172192
# Training: Episode = 415, Length = 8, Global step = 3932, Eps: 0.027979271678172192
# Training: Episode = 416, Length = 9, Global step = 3941, Eps: 0.027979271678172192
# Training: Episode = 417, Length = 10, Global step = 3951, Eps: 0.027979271678172192
# Training: Episode = 418, Length = 9, Global step = 3960, Eps: 0.027979271678172192
# Training: Episode = 419, Length = 11, Global step = 3971, Eps: 0.027979271678172192
# Training: Episode = 420, Length = 9, Global step = 3980, Eps: 0.027979271678172192
# Training: Episode = 421, Length = 9, Global step = 3989, Eps: 0.027979271678172192
# Training: Episode = 422, Length = 10, Global step = 3999, Eps: 0.027979271678172192
# Training: Episode = 423, Length = 10, Global step = 4009, Eps: 0.027979271678172192
# Training: Episode = 424, Length = 9, Global step = 4018, Eps: 0.027979271678172192
# Training: Episode = 425, Length = 8, Global step = 4026, Eps: 0.027979271678172192
# Training: Episode = 426, Length = 10, Global step = 4036, Eps: 0.027979271678172192
# Training: Episode = 427, Length = 11, Global step = 4047, Eps: 0.027979271678172192
# Training: Episode = 428, Length = 10, Global step = 4057, Eps: 0.027979271678172192
# Training: Episode = 429, Length = 9, Global step = 4066, Eps: 0.027979271678172192
# Training: Episode = 430, Length = 9, Global step = 4075, Eps: 0.027979271678172192
# Training: Episode = 431, Length = 10, Global step = 4085, Eps: 0.027979271678172192
# Training: Episode = 432, Length = 9, Global step = 4094, Eps: 0.027979271678172192
# Training: Episode = 433, Length = 10, Global step = 4104, Eps: 0.027979271678172192
# Training: Episode = 434, Length = 10, Global step = 4114, Eps: 0.027979271678172192
# Training: Episode = 435, Length = 10, Global step = 4124, Eps: 0.027979271678172192
# Training: Episode = 436, Length = 10, Global step = 4134, Eps: 0.027979271678172192
# Training: Episode = 437, Length = 10, Global step = 4144, Eps: 0.027979271678172192
# Training: Episode = 438, Length = 9, Global step = 4153, Eps: 0.027979271678172192
# Training: Episode = 439, Length = 9, Global step = 4162, Eps: 0.027979271678172192
# Training: Episode = 440, Length = 8, Global step = 4170, Eps: 0.027979271678172192
# Training: Episode = 441, Length = 10, Global step = 4180, Eps: 0.027979271678172192
# Training: Episode = 442, Length = 8, Global step = 4188, Eps: 0.027979271678172192
# Training: Episode = 443, Length = 9, Global step = 4197, Eps: 0.027979271678172192
# Training: Episode = 444, Length = 9, Global step = 4206, Eps: 0.027979271678172192
# Training: Episode = 445, Length = 10, Global step = 4216, Eps: 0.027979271678172192
# Training: Episode = 446, Length = 12, Global step = 4228, Eps: 0.027979271678172192
# Training: Episode = 447, Length = 10, Global step = 4238, Eps: 0.027979271678172192
# Training: Episode = 448, Length = 10, Global step = 4248, Eps: 0.027979271678172192
# Training: Episode = 449, Length = 9, Global step = 4257, Eps: 0.027979271678172192
# Training: Episode = 450, Length = 9, Global step = 4266, Eps: 0.027979271678172192
# Training: Episode = 451, Length = 10, Global step = 4276, Eps: 0.027979271678172192
# Training: Episode = 452, Length = 9, Global step = 4285, Eps: 0.027979271678172192
# Training: Episode = 453, Length = 9, Global step = 4294, Eps: 0.027979271678172192
# Training: Episode = 454, Length = 10, Global step = 4304, Eps: 0.027979271678172192
# Training: Episode = 455, Length = 9, Global step = 4313, Eps: 0.027979271678172192
# Training: Episode = 456, Length = 9, Global step = 4322, Eps: 0.027979271678172192
# Training: Episode = 457, Length = 9, Global step = 4331, Eps: 0.027979271678172192
# Training: Episode = 458, Length = 9, Global step = 4340, Eps: 0.027979271678172192
# Training: Episode = 459, Length = 9, Global step = 4349, Eps: 0.027979271678172192
# Training: Episode = 460, Length = 10, Global step = 4359, Eps: 0.027979271678172192
# Training: Episode = 461, Length = 10, Global step = 4369, Eps: 0.027979271678172192
# Training: Episode = 462, Length = 9, Global step = 4378, Eps: 0.027979271678172192
# Training: Episode = 463, Length = 9, Global step = 4387, Eps: 0.027979271678172192
# Training: Episode = 464, Length = 8, Global step = 4395, Eps: 0.027979271678172192
# Training: Episode = 465, Length = 10, Global step = 4405, Eps: 0.027979271678172192
# Training: Episode = 466, Length = 10, Global step = 4415, Eps: 0.027979271678172192
# Training: Episode = 467, Length = 11, Global step = 4426, Eps: 0.027979271678172192
# Training: Episode = 468, Length = 10, Global step = 4436, Eps: 0.027979271678172192
# Training: Episode = 469, Length = 9, Global step = 4445, Eps: 0.027979271678172192
# Training: Episode = 470, Length = 11, Global step = 4456, Eps: 0.027979271678172192
# Training: Episode = 471, Length = 10, Global step = 4466, Eps: 0.027979271678172192
# Training: Episode = 472, Length = 9, Global step = 4475, Eps: 0.027979271678172192
# Training: Episode = 473, Length = 9, Global step = 4484, Eps: 0.027979271678172192
# Training: Episode = 474, Length = 8, Global step = 4492, Eps: 0.027979271678172192
# Training: Episode = 475, Length = 9, Global step = 4501, Eps: 0.027979271678172192
# Training: Episode = 476, Length = 10, Global step = 4511, Eps: 0.027979271678172192
# Training: Episode = 477, Length = 9, Global step = 4520, Eps: 0.027979271678172192
# Training: Episode = 478, Length = 9, Global step = 4529, Eps: 0.027979271678172192
# Training: Episode = 479, Length = 10, Global step = 4539, Eps: 0.027979271678172192
# Training: Episode = 480, Length = 9, Global step = 4548, Eps: 0.027979271678172192
# Training: Episode = 481, Length = 9, Global step = 4557, Eps: 0.027979271678172192
# Training: Episode = 482, Length = 10, Global step = 4567, Eps: 0.027979271678172192
# Training: Episode = 483, Length = 10, Global step = 4577, Eps: 0.027979271678172192
# Training: Episode = 484, Length = 9, Global step = 4586, Eps: 0.027979271678172192
# Training: Episode = 485, Length = 9, Global step = 4595, Eps: 0.027979271678172192
# Training: Episode = 486, Length = 9, Global step = 4604, Eps: 0.027979271678172192
# Training: Episode = 487, Length = 12, Global step = 4616, Eps: 0.027979271678172192
# Training: Episode = 488, Length = 12, Global step = 4628, Eps: 0.027979271678172192
# Training: Episode = 489, Length = 10, Global step = 4638, Eps: 0.027979271678172192
# Training: Episode = 490, Length = 8, Global step = 4646, Eps: 0.027979271678172192
# Training: Episode = 491, Length = 9, Global step = 4655, Eps: 0.027979271678172192
# Training: Episode = 492, Length = 10, Global step = 4665, Eps: 0.027979271678172192
# Training: Episode = 493, Length = 9, Global step = 4674, Eps: 0.027979271678172192
# Training: Episode = 494, Length = 10, Global step = 4684, Eps: 0.027979271678172192
# Training: Episode = 495, Length = 10, Global step = 4694, Eps: 0.027979271678172192
# Training: Episode = 496, Length = 9, Global step = 4703, Eps: 0.027979271678172192
# Training: Episode = 497, Length = 9, Global step = 4712, Eps: 0.027979271678172192
# Training: Episode = 498, Length = 10, Global step = 4722, Eps: 0.027979271678172192
# Training: Episode = 499, Length = 9, Global step = 4731, Eps: 0.027979271678172192
# Training: Episode = 500, Length = 8, Global step = 4739, Eps: 0.027979271678172192
# Training: Episode = 501, Length = 9, Global step = 4748, Eps: 0.027979271678172192
# Training: Episode = 502, Length = 8, Global step = 4756, Eps: 0.027979271678172192
# Training: Episode = 503, Length = 10, Global step = 4766, Eps: 0.027979271678172192
# Training: Episode = 504, Length = 10, Global step = 4776, Eps: 0.027979271678172192
# Training: Episode = 505, Length = 9, Global step = 4785, Eps: 0.027979271678172192
# Training: Episode = 506, Length = 9, Global step = 4794, Eps: 0.027979271678172192
# Training: Episode = 507, Length = 9, Global step = 4803, Eps: 0.027979271678172192
# Training: Episode = 508, Length = 10, Global step = 4813, Eps: 0.027979271678172192
# Training: Episode = 509, Length = 9, Global step = 4822, Eps: 0.027979271678172192
# Training: Episode = 510, Length = 10, Global step = 4832, Eps: 0.027979271678172192
# Training: Episode = 511, Length = 10, Global step = 4842, Eps: 0.027979271678172192
# Training: Episode = 512, Length = 10, Global step = 4852, Eps: 0.027979271678172192
# Training: Episode = 513, Length = 10, Global step = 4862, Eps: 0.027979271678172192
# Training: Episode = 514, Length = 9, Global step = 4871, Eps: 0.027979271678172192
# Training: Episode = 515, Length = 12, Global step = 4883, Eps: 0.027979271678172192
# Training: Episode = 516, Length = 10, Global step = 4893, Eps: 0.027979271678172192
# Training: Episode = 517, Length = 8, Global step = 4901, Eps: 0.027979271678172192
# Training: Episode = 518, Length = 9, Global step = 4910, Eps: 0.027979271678172192
# Training: Episode = 519, Length = 10, Global step = 4920, Eps: 0.027979271678172192
# Training: Episode = 520, Length = 10, Global step = 4930, Eps: 0.027979271678172192
# Training: Episode = 521, Length = 10, Global step = 4940, Eps: 0.027979271678172192
# Training: Episode = 522, Length = 12, Global step = 4952, Eps: 0.027979271678172192
# Training: Episode = 523, Length = 10, Global step = 4962, Eps: 0.027979271678172192
# Training: Episode = 524, Length = 10, Global step = 4972, Eps: 0.027979271678172192
# Training: Episode = 525, Length = 10, Global step = 4982, Eps: 0.027979271678172192
# Training: Episode = 526, Length = 9, Global step = 4991, Eps: 0.027979271678172192
# Training: Episode = 527, Length = 10, Global step = 5001, Eps: 0.027979271678172192
# Training: Episode = 528, Length = 9, Global step = 5010, Eps: 0.027979271678172192
# Training: Episode = 529, Length = 10, Global step = 5020, Eps: 0.027979271678172192
# Training: Episode = 530, Length = 9, Global step = 5029, Eps: 0.027979271678172192
# Training: Episode = 531, Length = 11, Global step = 5040, Eps: 0.027979271678172192
# Training: Episode = 532, Length = 9, Global step = 5049, Eps: 0.027979271678172192
# Training: Episode = 533, Length = 10, Global step = 5059, Eps: 0.027979271678172192
# Training: Episode = 534, Length = 10, Global step = 5069, Eps: 0.027979271678172192
# Training: Episode = 535, Length = 11, Global step = 5080, Eps: 0.027979271678172192
# Training: Episode = 536, Length = 9, Global step = 5089, Eps: 0.027979271678172192
# Training: Episode = 537, Length = 10, Global step = 5099, Eps: 0.027979271678172192
# Training: Episode = 538, Length = 11, Global step = 5110, Eps: 0.027979271678172192
# Training: Episode = 539, Length = 9, Global step = 5119, Eps: 0.027979271678172192
# Training: Episode = 540, Length = 9, Global step = 5128, Eps: 0.027979271678172192
# Training: Episode = 541, Length = 10, Global step = 5138, Eps: 0.027979271678172192
# Training: Episode = 542, Length = 9, Global step = 5147, Eps: 0.027979271678172192
# Training: Episode = 543, Length = 11, Global step = 5158, Eps: 0.027979271678172192
# Training: Episode = 544, Length = 9, Global step = 5167, Eps: 0.027979271678172192
# Training: Episode = 545, Length = 10, Global step = 5177, Eps: 0.027979271678172192
# Training: Episode = 546, Length = 9, Global step = 5186, Eps: 0.027979271678172192
# Training: Episode = 547, Length = 10, Global step = 5196, Eps: 0.027979271678172192
# Training: Episode = 548, Length = 9, Global step = 5205, Eps: 0.027979271678172192
# Training: Episode = 549, Length = 10, Global step = 5215, Eps: 0.027979271678172192
# Training: Episode = 550, Length = 10, Global step = 5225, Eps: 0.027979271678172192
# Training: Episode = 551, Length = 9, Global step = 5234, Eps: 0.027979271678172192
# Training: Episode = 552, Length = 10, Global step = 5244, Eps: 0.027979271678172192
# Training: Episode = 553, Length = 10, Global step = 5254, Eps: 0.027979271678172192
# Training: Episode = 554, Length = 9, Global step = 5263, Eps: 0.027979271678172192
# Training: Episode = 555, Length = 9, Global step = 5272, Eps: 0.027979271678172192
# Training: Episode = 556, Length = 10, Global step = 5282, Eps: 0.027979271678172192
# Training: Episode = 557, Length = 11, Global step = 5293, Eps: 0.027979271678172192
# Training: Episode = 558, Length = 10, Global step = 5303, Eps: 0.027979271678172192
# Training: Episode = 559, Length = 8, Global step = 5311, Eps: 0.027979271678172192
# Training: Episode = 560, Length = 9, Global step = 5320, Eps: 0.027979271678172192
# Training: Episode = 561, Length = 10, Global step = 5330, Eps: 0.027979271678172192
# Training: Episode = 562, Length = 9, Global step = 5339, Eps: 0.027979271678172192
# Training: Episode = 563, Length = 11, Global step = 5350, Eps: 0.027979271678172192
# Training: Episode = 564, Length = 9, Global step = 5359, Eps: 0.027979271678172192
# Training: Episode = 565, Length = 10, Global step = 5369, Eps: 0.027979271678172192
# Training: Episode = 566, Length = 8, Global step = 5377, Eps: 0.027979271678172192
# Training: Episode = 567, Length = 11, Global step = 5388, Eps: 0.027979271678172192
# Training: Episode = 568, Length = 11, Global step = 5399, Eps: 0.027979271678172192
# Training: Episode = 569, Length = 10, Global step = 5409, Eps: 0.027979271678172192
# Training: Episode = 570, Length = 10, Global step = 5419, Eps: 0.027979271678172192
# Training: Episode = 571, Length = 10, Global step = 5429, Eps: 0.027979271678172192
# Training: Episode = 572, Length = 10, Global step = 5439, Eps: 0.027979271678172192
# Training: Episode = 573, Length = 9, Global step = 5448, Eps: 0.027979271678172192
# Training: Episode = 574, Length = 9, Global step = 5457, Eps: 0.027979271678172192
# Training: Episode = 575, Length = 9, Global step = 5466, Eps: 0.027979271678172192
# Training: Episode = 576, Length = 9, Global step = 5475, Eps: 0.027979271678172192
# ...
# Training: Episode = 1772, Length = 33, Global step = 22400, Eps: 0.02
# Training: Episode = 1773, Length = 33, Global step = 22433, Eps: 0.02
# Training: Episode = 1774, Length = 29, Global step = 22462, Eps: 0.02
# Training: Episode = 1775, Length = 29, Global step = 22491, Eps: 0.02
# Training: Episode = 1776, Length = 28, Global step = 22519, Eps: 0.02
# Training: Episode = 1777, Length = 32, Global step = 22551, Eps: 0.02
# Training: Episode = 1778, Length = 33, Global step = 22584, Eps: 0.02
# Training: Episode = 1779, Length = 34, Global step = 22618, Eps: 0.02
# Training: Episode = 1780, Length = 30, Global step = 22648, Eps: 0.02
# Training: Episode = 1781, Length = 41, Global step = 22689, Eps: 0.02
# Training: Episode = 1782, Length = 37, Global step = 22726, Eps: 0.02
# Training: Episode = 1783, Length = 20, Global step = 22746, Eps: 0.02
# Training: Episode = 1784, Length = 33, Global step = 22779, Eps: 0.02
# Training: Episode = 1785, Length = 48, Global step = 22827, Eps: 0.02
# Training: Episode = 1786, Length = 20, Global step = 22847, Eps: 0.02
# Training: Episode = 1787, Length = 28, Global step = 22875, Eps: 0.02
# Training: Episode = 1788, Length = 35, Global step = 22910, Eps: 0.02
# Training: Episode = 1789, Length = 36, Global step = 22946, Eps: 0.02
# Training: Episode = 1790, Length = 45, Global step = 22991, Eps: 0.02
# Training: Episode = 1791, Length = 31, Global step = 23022, Eps: 0.02
# Training: Episode = 1792, Length = 36, Global step = 23058, Eps: 0.02
# Training: Episode = 1793, Length = 10, Global step = 23068, Eps: 0.02
# Training: Episode = 1794, Length = 36, Global step = 23104, Eps: 0.02
# Training: Episode = 1795, Length = 19, Global step = 23123, Eps: 0.02
# Training: Episode = 1796, Length = 33, Global step = 23156, Eps: 0.02
# Training: Episode = 1797, Length = 29, Global step = 23185, Eps: 0.02
# Training: Episode = 1798, Length = 29, Global step = 23214, Eps: 0.02
# Training: Episode = 1799, Length = 38, Global step = 23252, Eps: 0.02
# Training: Episode = 1800, Length = 35, Global step = 23287, Eps: 0.02
# Training: Episode = 1801, Length = 36, Global step = 23323, Eps: 0.02
# Training: Episode = 1802, Length = 29, Global step = 23352, Eps: 0.02
# Training: Episode = 1803, Length = 18, Global step = 23370, Eps: 0.02
# Training: Episode = 1804, Length = 30, Global step = 23400, Eps: 0.02
# Training: Episode = 1805, Length = 26, Global step = 23426, Eps: 0.02
# Training: Episode = 1806, Length = 11, Global step = 23437, Eps: 0.02
# Training: Episode = 1807, Length = 8, Global step = 23445, Eps: 0.02
# Training: Episode = 1808, Length = 9, Global step = 23454, Eps: 0.02
# Training: Episode = 1809, Length = 32, Global step = 23486, Eps: 0.02
# Training: Episode = 1810, Length = 19, Global step = 23505, Eps: 0.02
# Training: Episode = 1811, Length = 26, Global step = 23531, Eps: 0.02
# Training: Episode = 1812, Length = 29, Global step = 23560, Eps: 0.02
# Training: Episode = 1813, Length = 40, Global step = 23600, Eps: 0.02
# Training: Episode = 1814, Length = 16, Global step = 23616, Eps: 0.02
# Training: Episode = 1815, Length = 14, Global step = 23630, Eps: 0.02
# Training: Episode = 1816, Length = 16, Global step = 23646, Eps: 0.02
# Training: Episode = 1817, Length = 29, Global step = 23675, Eps: 0.02
# Training: Episode = 1818, Length = 16, Global step = 23691, Eps: 0.02
# Training: Episode = 1819, Length = 19, Global step = 23710, Eps: 0.02
# Training: Episode = 1820, Length = 22, Global step = 23732, Eps: 0.02
# Training: Episode = 1821, Length = 22, Global step = 23754, Eps: 0.02
# Training: Episode = 1822, Length = 21, Global step = 23775, Eps: 0.02
# Training: Episode = 1823, Length = 29, Global step = 23804, Eps: 0.02
# Training: Episode = 1824, Length = 26, Global step = 23830, Eps: 0.02
# Training: Episode = 1825, Length = 14, Global step = 23844, Eps: 0.02
# Training: Episode = 1826, Length = 10, Global step = 23854, Eps: 0.02
# Training: Episode = 1827, Length = 27, Global step = 23881, Eps: 0.02
# Training: Episode = 1828, Length = 37, Global step = 23918, Eps: 0.02
# Training: Episode = 1829, Length = 30, Global step = 23948, Eps: 0.02
# Training: Episode = 1830, Length = 27, Global step = 23975, Eps: 0.02
# Training: Episode = 1831, Length = 11, Global step = 23986, Eps: 0.02
# Training: Episode = 1832, Length = 25, Global step = 24011, Eps: 0.02
# Training: Episode = 1833, Length = 24, Global step = 24035, Eps: 0.02
# Training: Episode = 1834, Length = 25, Global step = 24060, Eps: 0.02
# Training: Episode = 1835, Length = 29, Global step = 24089, Eps: 0.02
# Training: Episode = 1836, Length = 29, Global step = 24118, Eps: 0.02
# Training: Episode = 1837, Length = 12, Global step = 24130, Eps: 0.02
# Training: Episode = 1838, Length = 13, Global step = 24143, Eps: 0.02
# Training: Episode = 1839, Length = 21, Global step = 24164, Eps: 0.02
# Training: Episode = 1840, Length = 12, Global step = 24176, Eps: 0.02
# Training: Episode = 1841, Length = 29, Global step = 24205, Eps: 0.02
# Training: Episode = 1842, Length = 29, Global step = 24234, Eps: 0.02
# Training: Episode = 1843, Length = 35, Global step = 24269, Eps: 0.02
# Training: Episode = 1844, Length = 20, Global step = 24289, Eps: 0.02
# Training: Episode = 1845, Length = 25, Global step = 24314, Eps: 0.02
# Training: Episode = 1846, Length = 22, Global step = 24336, Eps: 0.02
# Training: Episode = 1847, Length = 17, Global step = 24353, Eps: 0.02
# Training: Episode = 1848, Length = 24, Global step = 24377, Eps: 0.02
# Training: Episode = 1849, Length = 22, Global step = 24399, Eps: 0.02
# Training: Episode = 1850, Length = 17, Global step = 24416, Eps: 0.02
# Training: Episode = 1851, Length = 20, Global step = 24436, Eps: 0.02
# Training: Episode = 1852, Length = 20, Global step = 24456, Eps: 0.02
# Training: Episode = 1853, Length = 14, Global step = 24470, Eps: 0.02
# Training: Episode = 1854, Length = 28, Global step = 24498, Eps: 0.02
# Training: Episode = 1855, Length = 21, Global step = 24519, Eps: 0.02
# Training: Episode = 1856, Length = 9, Global step = 24528, Eps: 0.02
# Training: Episode = 1857, Length = 9, Global step = 24537, Eps: 0.02
# Training: Episode = 1858, Length = 9, Global step = 24546, Eps: 0.02
# Training: Episode = 1859, Length = 9, Global step = 24555, Eps: 0.02
# Training: Episode = 1860, Length = 9, Global step = 24564, Eps: 0.02
# Training: Episode = 1861, Length = 9, Global step = 24573, Eps: 0.02
# Training: Episode = 1862, Length = 10, Global step = 24583, Eps: 0.02
# Training: Episode = 1863, Length = 9, Global step = 24592, Eps: 0.02
# Training: Episode = 1864, Length = 10, Global step = 24602, Eps: 0.02
# Training: Episode = 1865, Length = 8, Global step = 24610, Eps: 0.02
# Training: Episode = 1866, Length = 9, Global step = 24619, Eps: 0.02
# Training: Episode = 1867, Length = 12, Global step = 24631, Eps: 0.02
# Training: Episode = 1868, Length = 10, Global step = 24641, Eps: 0.02
# Training: Episode = 1869, Length = 10, Global step = 24651, Eps: 0.02
# Training: Episode = 1870, Length = 11, Global step = 24662, Eps: 0.02
# Training: Episode = 1871, Length = 10, Global step = 24672, Eps: 0.02
# Training: Episode = 1872, Length = 10, Global step = 24682, Eps: 0.02
# Training: Episode = 1873, Length = 9, Global step = 24691, Eps: 0.02
# Training: Episode = 1874, Length = 9, Global step = 24700, Eps: 0.02
# Training: Episode = 1875, Length = 9, Global step = 24709, Eps: 0.02
# Training: Episode = 1876, Length = 9, Global step = 24718, Eps: 0.02
# Training: Episode = 1877, Length = 10, Global step = 24728, Eps: 0.02
# Training: Episode = 1878, Length = 10, Global step = 24738, Eps: 0.02
# Training: Episode = 1879, Length = 10, Global step = 24748, Eps: 0.02
# Training: Episode = 1880, Length = 10, Global step = 24758, Eps: 0.02
# Training: Episode = 1881, Length = 10, Global step = 24768, Eps: 0.02
# Training: Episode = 1882, Length = 9, Global step = 24777, Eps: 0.02
# Training: Episode = 1883, Length = 11, Global step = 24788, Eps: 0.02
# Training: Episode = 1884, Length = 10, Global step = 24798, Eps: 0.02
# Training: Episode = 1885, Length = 9, Global step = 24807, Eps: 0.02
# Training: Episode = 1886, Length = 9, Global step = 24816, Eps: 0.02
# Training: Episode = 1887, Length = 10, Global step = 24826, Eps: 0.02
# Training: Episode = 1888, Length = 9, Global step = 24835, Eps: 0.02
# Training: Episode = 1889, Length = 9, Global step = 24844, Eps: 0.02
# Training: Episode = 1890, Length = 9, Global step = 24853, Eps: 0.02
# Training: Episode = 1891, Length = 10, Global step = 24863, Eps: 0.02
# Training: Episode = 1892, Length = 9, Global step = 24872, Eps: 0.02
# Training: Episode = 1893, Length = 8, Global step = 24880, Eps: 0.02
# Training: Episode = 1894, Length = 10, Global step = 24890, Eps: 0.02
# Training: Episode = 1895, Length = 9, Global step = 24899, Eps: 0.02
# Training: Episode = 1896, Length = 10, Global step = 24909, Eps: 0.02
# Training: Episode = 1897, Length = 10, Global step = 24919, Eps: 0.02
# Training: Episode = 1898, Length = 9, Global step = 24928, Eps: 0.02
# Training: Episode = 1899, Length = 9, Global step = 24937, Eps: 0.02
# Training: Episode = 1900, Length = 9, Global step = 24946, Eps: 0.02
# Training: Episode = 1901, Length = 9, Global step = 24955, Eps: 0.02
# Training: Episode = 1902, Length = 8, Global step = 24963, Eps: 0.02
# Training: Episode = 1903, Length = 8, Global step = 24971, Eps: 0.02
# Training: Episode = 1904, Length = 11, Global step = 24982, Eps: 0.02
# Training: Episode = 1905, Length = 8, Global step = 24990, Eps: 0.02
# Training: Episode = 1906, Length = 8, Global step = 24998, Eps: 0.02
# Training: Episode = 1907, Length = 9, Global step = 25007, Eps: 0.02
# Training: Episode = 1908, Length = 9, Global step = 25016, Eps: 0.02
# Training: Episode = 1909, Length = 9, Global step = 25025, Eps: 0.02
# Training: Episode = 1910, Length = 10, Global step = 25035, Eps: 0.02
# Training: Episode = 1911, Length = 10, Global step = 25045, Eps: 0.02
# Training: Episode = 1912, Length = 9, Global step = 25054, Eps: 0.02
# Training: Episode = 1913, Length = 9, Global step = 25063, Eps: 0.02
# Training: Episode = 1914, Length = 10, Global step = 25073, Eps: 0.02
# Training: Episode = 1915, Length = 10, Global step = 25083, Eps: 0.02
# Training: Episode = 1916, Length = 9, Global step = 25092, Eps: 0.02
# Training: Episode = 1917, Length = 9, Global step = 25101, Eps: 0.02
# Training: Episode = 1918, Length = 9, Global step = 25110, Eps: 0.02
# Training: Episode = 1919, Length = 8, Global step = 25118, Eps: 0.02
# Training: Episode = 1920, Length = 9, Global step = 25127, Eps: 0.02
# Training: Episode = 1921, Length = 12, Global step = 25139, Eps: 0.02
# Training: Episode = 1922, Length = 12, Global step = 25151, Eps: 0.02
# Training: Episode = 1923, Length = 8, Global step = 25159, Eps: 0.02
# Training: Episode = 1924, Length = 9, Global step = 25168, Eps: 0.02
# Training: Episode = 1925, Length = 9, Global step = 25177, Eps: 0.02
# Training: Episode = 1926, Length = 10, Global step = 25187, Eps: 0.02
# Training: Episode = 1927, Length = 10, Global step = 25197, Eps: 0.02
# Training: Episode = 1928, Length = 10, Global step = 25207, Eps: 0.02
# Training: Episode = 1929, Length = 10, Global step = 25217, Eps: 0.02
# Training: Episode = 1930, Length = 9, Global step = 25226, Eps: 0.02
# Training: Episode = 1931, Length = 10, Global step = 25236, Eps: 0.02
# Training: Episode = 1932, Length = 10, Global step = 25246, Eps: 0.02
# Training: Episode = 1933, Length = 9, Global step = 25255, Eps: 0.02
# Training: Episode = 1934, Length = 9, Global step = 25264, Eps: 0.02
# Training: Episode = 1935, Length = 10, Global step = 25274, Eps: 0.02
# Training: Episode = 1936, Length = 8, Global step = 25282, Eps: 0.02
# Training: Episode = 1937, Length = 10, Global step = 25292, Eps: 0.02
# Training: Episode = 1938, Length = 9, Global step = 25301, Eps: 0.02
# Training: Episode = 1939, Length = 8, Global step = 25309, Eps: 0.02
# Training: Episode = 1940, Length = 10, Global step = 25319, Eps: 0.02
# Training: Episode = 1941, Length = 10, Global step = 25329, Eps: 0.02
# Training: Episode = 1942, Length = 9, Global step = 25338, Eps: 0.02
# Training: Episode = 1943, Length = 9, Global step = 25347, Eps: 0.02
# Training: Episode = 1944, Length = 11, Global step = 25358, Eps: 0.02
# Training: Episode = 1945, Length = 10, Global step = 25368, Eps: 0.02
# Training: Episode = 1946, Length = 10, Global step = 25378, Eps: 0.02
# Training: Episode = 1947, Length = 10, Global step = 25388, Eps: 0.02
# Training: Episode = 1948, Length = 10, Global step = 25398, Eps: 0.02
# Training: Episode = 1949, Length = 9, Global step = 25407, Eps: 0.02
# Training: Episode = 1950, Length = 10, Global step = 25417, Eps: 0.02
# Training: Episode = 1951, Length = 9, Global step = 25426, Eps: 0.02
# Training: Episode = 1952, Length = 9, Global step = 25435, Eps: 0.02
# Training: Episode = 1953, Length = 8, Global step = 25443, Eps: 0.02
# Training: Episode = 1954, Length = 11, Global step = 25454, Eps: 0.02
# Training: Episode = 1955, Length = 10, Global step = 25464, Eps: 0.02
# Training: Episode = 1956, Length = 9, Global step = 25473, Eps: 0.02
# Training: Episode = 1957, Length = 10, Global step = 25483, Eps: 0.02
# Training: Episode = 1958, Length = 10, Global step = 25493, Eps: 0.02
# Training: Episode = 1959, Length = 10, Global step = 25503, Eps: 0.02
# Training: Episode = 1960, Length = 9, Global step = 25512, Eps: 0.02
# Training: Episode = 1961, Length = 9, Global step = 25521, Eps: 0.02
# Training: Episode = 1962, Length = 8, Global step = 25529, Eps: 0.02
# Training: Episode = 1963, Length = 9, Global step = 25538, Eps: 0.02
# Training: Episode = 1964, Length = 11, Global step = 25549, Eps: 0.02
# Training: Episode = 1965, Length = 11, Global step = 25560, Eps: 0.02
# Training: Episode = 1966, Length = 10, Global step = 25570, Eps: 0.02
# Training: Episode = 1967, Length = 10, Global step = 25580, Eps: 0.02
# Training: Episode = 1968, Length = 10, Global step = 25590, Eps: 0.02
# Training: Episode = 1969, Length = 9, Global step = 25599, Eps: 0.02
# Training: Episode = 1970, Length = 10, Global step = 25609, Eps: 0.02
# Training: Episode = 1971, Length = 8, Global step = 25617, Eps: 0.02
# Training: Episode = 1972, Length = 9, Global step = 25626, Eps: 0.02
# Training: Episode = 1973, Length = 9, Global step = 25635, Eps: 0.02
# Training: Episode = 1974, Length = 10, Global step = 25645, Eps: 0.02
# Training: Episode = 1975, Length = 10, Global step = 25655, Eps: 0.02
# Training: Episode = 1976, Length = 10, Global step = 25665, Eps: 0.02
# Training: Episode = 1977, Length = 9, Global step = 25674, Eps: 0.02
# Training: Episode = 1978, Length = 10, Global step = 25684, Eps: 0.02
# Training: Episode = 1979, Length = 8, Global step = 25692, Eps: 0.02
# Training: Episode = 1980, Length = 8, Global step = 25700, Eps: 0.02
# Training: Episode = 1981, Length = 10, Global step = 25710, Eps: 0.02
# Training: Episode = 1982, Length = 9, Global step = 25719, Eps: 0.02
# Training: Episode = 1983, Length = 10, Global step = 25729, Eps: 0.02
# Training: Episode = 1984, Length = 9, Global step = 25738, Eps: 0.02
# Training: Episode = 1985, Length = 10, Global step = 25748, Eps: 0.02
# Training: Episode = 1986, Length = 10, Global step = 25758, Eps: 0.02
# Training: Episode = 1987, Length = 8, Global step = 25766, Eps: 0.02
# Training: Episode = 1988, Length = 9, Global step = 25775, Eps: 0.02
# Training: Episode = 1989, Length = 8, Global step = 25783, Eps: 0.02
# Training: Episode = 1990, Length = 13, Global step = 25796, Eps: 0.02
# Training: Episode = 1991, Length = 9, Global step = 25805, Eps: 0.02
# Training: Episode = 1992, Length = 9, Global step = 25814, Eps: 0.02
# Training: Episode = 1993, Length = 10, Global step = 25824, Eps: 0.02
# Training: Episode = 1994, Length = 8, Global step = 25832, Eps: 0.02
# Training: Episode = 1995, Length = 9, Global step = 25841, Eps: 0.02
# Training: Episode = 1996, Length = 10, Global step = 25851, Eps: 0.02
# Training: Episode = 1997, Length = 10, Global step = 25861, Eps: 0.02
# Training: Episode = 1998, Length = 10, Global step = 25871, Eps: 0.02
# Training: Episode = 1999, Length = 10, Global step = 25881, Eps: 0.02
#
# Finished training...
# Check out some demonstrations

# %%
replay_batch = np.array(rd.sample(dqn.replay_buffer,dqn.MINIBATCH_SIZE))
nst = []
st = []
acts = []
for y in replay_batch:
    nst.append(y[3])
    st.append(y[0])
    acts.append(y[1])
max_Q = np.amax(dqn.model.predict(np.array(nst),1))
tgts = replay_batch[:,2] + dqn.DISCOUNT_FACTOR * max_Q * (1-replay_batch[:,4])
batch_targets = dqn.model.predict(np.array(st))

# %%
print(batch_targets[1],tgts[1])
batch_targets[:,list(replay_batch[:,1])] = tgts
for y in range(len(batch_targets)):
    batch_targets[y][replay_batch[y,1]] = tgts[y]
print(batch_targets[1],replay_batch[1,1])
# x = [1,2,3]
# batch_targets[x]

# %%
dqn.model.fit(np.array(st), batch_targets,epochs=1, verbose = 0, workers=8, use_multiprocessing=True)
batch_targets

# %%
max_Q

# %%
batch_targets

# %%
# average steps
results = []
for i in range(50):
    episode_length = dqn.playPolicy()
    print("Test steps = ", episode_length)
    results.append(episode_length)
print("Mean steps = ", sum(results) / len(results))	
dqn.env.close()
print("\nFinished.")
print("\nCiao, and hasta la vista...\n")

# %%
ep_rwd =  dqn.episodic_rewards
avg_eprwd = []
tot = 0
for i in range(1,100):
    avg_eprwd.append(tot/i)
    tot += ep_rwd[i]
for i in range(100,len(ep_rwd)):
    tot += ep_rwd[i]
    tot -= ep_rwd[i-100]
    avg_eprwd.append(tot/100)
plt.plot(ep_rwd,'c',linewidth=0.3)
plt.plot(avg_eprwd,'b',linewidth=2)
plt.xlabel('Episodes')
plt.ylabel('Average Reward for every '+str(100)+' Episodes')
plt.title('DQN, Cart-pole, no target network')
plt.show()

# %%
dqn.save_model('dqn_weights_final_notgtQ')
np.save('dqn_ep_rwd_final_notgtQ.npy',dqn.episodic_rewards)
# Out:
# WARNING:tensorflow:From /home/subbu/.local/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: dqn_weights_final_notgtQ/assets

# %%
# to visualize it No need to train again

dqn_vis = DQN('CartPole-v0')
dqn_vis.load_model('dqn_weights_final_notgtQ') # loading trained model from memory
for i in range(10):
    done = False
    steps = 0
    state = dqn_vis.env.reset()

    while not done and steps < 200: 
        dqn_vis.env.render()
        action = np.argmax(dqn_vis.model.predict(np.array([state]))[0])
        state, _, done, _ = dqn_vis.env.step(action)
        steps += 1
        
    print('Steps:'+str(steps))

dqn_vis.env.close()

# %%
# to visualize it No need to train again

ep_rwd = np.load('dqn_ep_rwd_final_notgtQ.npy') # loading training data from memory
avg_eprwd = []
tot = 0
for i in range(1,100):
    avg_eprwd.append(tot/i)
    tot += ep_rwd[i]
for i in range(100,len(ep_rwd)):
    tot += ep_rwd[i]
    tot -= ep_rwd[i-100]
    avg_eprwd.append(tot/100)
plt.plot(ep_rwd,'c',linewidth=0.3)
plt.plot(avg_eprwd,'b',linewidth=2)
plt.xlabel('Episodes')
plt.ylabel('Average Reward for every '+str(100)+' Episodes')
plt.title('DQN, Cart-pole, no target network')
plt.show()
