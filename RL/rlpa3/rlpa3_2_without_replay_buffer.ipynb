# %%
# imports

import gym
import random as rd
from collections import deque
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %% [markdown]
#     Observations
#     1. On decreasing target update freq the varience of model increasing and on increasing convergence is taking longer
#     2. low discount factors unable to clearly differentiate the increase in steps after some treshlod
#     3. Increasing mini batch helping to achieve convergence faster
#     4.

# %%
# implementing DQN class

class DQN:

    REPLAY_MEMORY_SIZE = 1 			# number of tuples in experience replay  
    EPSILON = 0.5 						# epsilon of epsilon-greedy exploation
    EPSILON_DECAY = 0.999 				# exponential decay multiplier for epsilon
    HIDDEN1_SIZE = 32 					# size of hidden layer 1 --> try 16*
    HIDDEN2_SIZE = 16 					# size of hidden layer 2
    EPISODES_NUM = 2000 				# number of episodes to train on. Ideally shouldn't take longer than 2000
    MAX_STEPS = 200 					# maximum number of steps in an episode 
    LEARNING_RATE = 0.001 				# learning rate and other parameters for SGD/RMSProp/Adam --> try 0.001*, 0.003
    MINIBATCH_SIZE = 1 				# size of minibatch sampled from the experience replay --> try 16*, 8
    DISCOUNT_FACTOR = 0.999 				# MDP's gamma --> try 0.999*, 0.99
    TARGET_UPDATE_FREQ = 50 			# number of steps (not episodes) after which to update the target networks --> try 50, 20*     
    LOG_DIR = './logs' 					# directory wherein logging takes place
    EPSILON_MIN = 0.02


    # Create and initialize the environment
    def __init__(self, env):
        self.env = gym.make(env)
        assert len(self.env.observation_space.shape) == 1
        self.input_size = self.env.observation_space.shape[0]		# In case of cartpole, 4 state features
        self.output_size = self.env.action_space.n					# In case of cartpole, 2 actions (right/left)
        self.eps = self.EPSILON
        self.episodic_rewards = []
        self.episodic_steps = []

    # Create the Q-network
    def initialize_network(self):
        
        ############################################################
        # Design your q-network here.
        # 
        # Add hidden layers and the output layer. For instance:
        # 
        # with tf.name_scope('output'):
        #	W_n = tf.Variable(
        # 			 tf.truncated_normal([self.HIDDEN_n-1_SIZE, self.output_size], 
        # 			 stddev=0.01), name='W_n')
        # 	b_n = tf.Variable(tf.zeros(self.output_size), name='b_n')
        # 	self.Q = tf.matmul(h_n-1, W_n) + b_n
        #
        #############################################################
        
        # Model designed using keras layers
        self.model = keras.Sequential([
                layers.InputLayer(input_shape=(self.input_size,)),
                layers.Dense(self.HIDDEN1_SIZE, activation='relu', name='hidden1', kernel_initializer='RandomNormal'),
                layers.Dense(self.HIDDEN2_SIZE, activation='relu', name='hidden2', kernel_initializer='RandomNormal'),
                layers.Dense(self.output_size, activation='linear', name='output', kernel_initializer='RandomNormal')
        ])

        ############################################################
        # Next, compute the loss.
        #
        # First, compute the q-values. Note that you need to calculate these
        # for the actions in the (s,a,s',r) tuples from the experience replay's minibatch
        #
        # Next, compute the l2 loss between these estimated q-values and 
        # the target (which is computed using the frozen target network)
        #
        ############################################################
        
        ############################################################
        # Finally, choose a gradient descent algorithm : SGD/RMSProp/Adam. 
        #
        # For instance:
        # optimizer = tf.train.GradientDescentOptimizer(self.LEARNING_RATE)
        # global_step = tf.Variable(0, name='global_step', trainable=False)
        # self.train_op = optimizer.minimize(self.loss, global_step=global_step)
        #
        ############################################################

        # Assigned descent algo. and loss function in one line
        self.model.compile(loss=keras.losses.MeanSquaredError(),optimizer=keras.optimizers.Adam(lr=self.LEARNING_RATE))
        self.model.summary()
        
        # create a target model a clone to our model i.e. target network
        self.target_model = keras.models.clone_model(self.model)
        self.target_model.build((None, self.input_size))
        self.target_model.compile(loss=keras.losses.MeanSquaredError(),optimizer=keras.optimizers.Adam(lr=self.LEARNING_RATE))
        self.target_model.set_weights(self.model.get_weights())

        ############################################################

    def train(self, episodes_num=EPISODES_NUM):

        # Initialize summary for TensorBoard 
        summary_writer = tf.summary.create_file_writer(self.LOG_DIR)
        summary = tf.summary
        # Alternatively, you could use animated real-time plots from matplotlib 
        # (https://stackoverflow.com/a/24228275/3284912)

        ############################################################
        # Initialize other variables (like the replay memory)
        ############################################################
        
        # Using deque
        self.replay_buffer = deque(maxlen=self.REPLAY_MEMORY_SIZE)
        total_steps = 0

        ############################################################
        # Main training loop
        # 
        # In each episode, 
        #	pick the action for the given state, 
        #	perform a 'step' in the environment to get the reward and next state,
        #	update the replay buffer,
        #	sample a random minibatch from the replay buffer,
        # 	perform Q-learning,
        #	update the target network, if required.
        #
        #
        #
        # You'll need to write code in various places in the following skeleton
        #
        ############################################################

        for episode in range(episodes_num):

            state = np.array([self.env.reset()])

            ############################################################
            # Episode-specific initializations go here.
            ############################################################
            
            episode_length = 0
            score = 0
            
            ############################################################

            while True:
                ############################################################
                # Pick the next action using epsilon greedy and execute it
                ############################################################
                episode_length += 1
                total_steps += 1
                if(rd.random() < self.eps):
                    act = self.env.action_space.sample()
                else:
                    act = np.argmax(self.model.predict(state)[0])

                ############################################################
                # Step in the environment. Something like: 
                # next_state, reward, done, _ = self.env.step(action)
                ############################################################

                next_state, reward, done, _ = self.env.step(act)
                next_state = np.array([next_state])
                
                ############################################################
                # Update the (limited) replay buffer. 
                #
                # Note : when the replay buffer is full, you'll need to 
                # remove an entry to accommodate a new one.
                ############################################################

                # The max length in deque removes oldest if buffer size exceeds it
                self.replay_buffer.append((state,act,reward,next_state,done))
                score += reward
                state = next_state

                ############################################################
                # Sample a random minibatch and perform Q-learning (fetch max Q at s') 
                #
                # Remember, the target (r + gamma * max Q) is computed    
                # with the help of the target network.
                # Compute this target and pass it to the network for computing 
                # and minimizing the loss with the current estimates
                #
                ############################################################
                
                # not starting network update until it has a batch size elements
                if len(self.replay_buffer) == self.REPLAY_MEMORY_SIZE:
                    batch_states = []
                    batch_targets = []
                    replay_batch = rd.sample(self.replay_buffer,self.MINIBATCH_SIZE)
                    for st, act, rwd, nst, d in replay_batch:
                        if d:
                            y = rwd
                        else:
                            y = (rwd + self.DISCOUNT_FACTOR * np.max(self.target_model.predict(nst)[0]))
                        tgt = self.model.predict(st)[0]
                        tgt[act] = y
                        batch_states.append(st[0])
                        batch_targets.append(tgt)
                        
                    batch_states = np.array(batch_states)
                    batch_targets = np.array(batch_targets)
                    self.model.fit(batch_states, batch_targets, epochs=1, verbose = 0, workers=8, use_multiprocessing=True)
                    
                    if self.eps > self.EPSILON_MIN:
                        self.eps *= self.EPSILON_DECAY
                    elif self.eps < self.EPSILON_MIN:
                        self.eps = self.EPSILON_MIN

                ############################################################
                # Update target weights. 
                #
                # Something along the lines of:
                # if total_steps % self.TARGET_UPDATE_FREQ == 0:
                # 	target_weights = self.session.run(self.weights)
                ############################################################

                if total_steps%self.TARGET_UPDATE_FREQ == 0:
                    self.target_model.set_weights(self.model.get_weights())

                ############################################################
                # Break out of the loop if the episode ends
                #
                # Something like:
                # if done or (episode_length == self.MAX_STEPS):
                # 	break
                #
                ############################################################
                
                if done or episode_length == self.MAX_STEPS:
                    self.episodic_rewards.append(score)
                    self.episodic_steps.append(episode_length)
                    break


            ############################################################
            # Logging. 
            #
            # Very important. This is what gives an idea of how good the current
            # experiment is, and if one should terminate and re-run with new parameters
            # The earlier you learn how to read and visualize experiment logs quickly,
            # the faster you'll be able to prototype and learn.
            #
            # Use any debugging information you think you need.
            # For instance :

            print("Training: Episode = %d, Length = %d, Global step = %d" % (episode, episode_length, total_steps),end=', ')
            print('Eps: '+str(self.eps))
            with summary_writer.as_default():
                summary.scalar("episode length",episode ,step=episode_length)
    
    def save_model(self, name):
        self.target_model.save(name)
        
    def load_model(self, name):
        self.model = keras.models.load_model(name)
        self.target_model = keras.models.load_model(name)

    # Simple function to visually 'test' a policy
    def playPolicy(self):

        done = False
        steps = 0
        state = self.env.reset()

        # we assume the CartPole task to be solved if the pole remains upright for 200 steps
        while not done and steps < 200: 
            # self.env.render()
            action = np.argmax(self.target_model.predict(np.array([state]))[0])
            state, _, done, _ = self.env.step(action)
            steps += 1

        return steps

# %%
# Create and initialize the model
# dqn = DQN('CartPole-v0')
# dqn.initialize_network()
print("\nStarting training...\n")
dqn.train(episodes_num=500)
print("\nFinished training...\nCheck out some demonstrations\n")
# Out:
# Starting training...
#
# Training: Episode = 0, Length = 200, Global step = 200, Eps: 0.02
# Training: Episode = 1, Length = 200, Global step = 400, Eps: 0.02
# Training: Episode = 2, Length = 200, Global step = 600, Eps: 0.02
# Training: Episode = 3, Length = 200, Global step = 800, Eps: 0.02
# Training: Episode = 4, Length = 200, Global step = 1000, Eps: 0.02
# Training: Episode = 5, Length = 14, Global step = 1014, Eps: 0.02
# Training: Episode = 6, Length = 8, Global step = 1022, Eps: 0.02
# Training: Episode = 7, Length = 10, Global step = 1032, Eps: 0.02
# Training: Episode = 8, Length = 10, Global step = 1042, Eps: 0.02
# Training: Episode = 9, Length = 10, Global step = 1052, Eps: 0.02
# Training: Episode = 10, Length = 10, Global step = 1062, Eps: 0.02
# Training: Episode = 11, Length = 9, Global step = 1071, Eps: 0.02
# Training: Episode = 12, Length = 9, Global step = 1080, Eps: 0.02
# Training: Episode = 13, Length = 10, Global step = 1090, Eps: 0.02
# Training: Episode = 14, Length = 11, Global step = 1101, Eps: 0.02
# Training: Episode = 15, Length = 10, Global step = 1111, Eps: 0.02
# Training: Episode = 16, Length = 10, Global step = 1121, Eps: 0.02
# Training: Episode = 17, Length = 10, Global step = 1131, Eps: 0.02
# Training: Episode = 18, Length = 9, Global step = 1140, Eps: 0.02
# Training: Episode = 19, Length = 10, Global step = 1150, Eps: 0.02
# Training: Episode = 20, Length = 9, Global step = 1159, Eps: 0.02
# Training: Episode = 21, Length = 9, Global step = 1168, Eps: 0.02
# Training: Episode = 22, Length = 10, Global step = 1178, Eps: 0.02
# Training: Episode = 23, Length = 8, Global step = 1186, Eps: 0.02
# Training: Episode = 24, Length = 10, Global step = 1196, Eps: 0.02
# Training: Episode = 25, Length = 9, Global step = 1205, Eps: 0.02
# Training: Episode = 26, Length = 10, Global step = 1215, Eps: 0.02
# Training: Episode = 27, Length = 11, Global step = 1226, Eps: 0.02
# Training: Episode = 28, Length = 8, Global step = 1234, Eps: 0.02
# Training: Episode = 29, Length = 10, Global step = 1244, Eps: 0.02
# Training: Episode = 30, Length = 10, Global step = 1254, Eps: 0.02
# Training: Episode = 31, Length = 10, Global step = 1264, Eps: 0.02
# Training: Episode = 32, Length = 13, Global step = 1277, Eps: 0.02
# Training: Episode = 33, Length = 14, Global step = 1291, Eps: 0.02
# Training: Episode = 34, Length = 12, Global step = 1303, Eps: 0.02
# Training: Episode = 35, Length = 37, Global step = 1340, Eps: 0.02
# Training: Episode = 36, Length = 200, Global step = 1540, Eps: 0.02
# Training: Episode = 37, Length = 200, Global step = 1740, Eps: 0.02
# Training: Episode = 38, Length = 200, Global step = 1940, Eps: 0.02
# Training: Episode = 39, Length = 200, Global step = 2140, Eps: 0.02
# Training: Episode = 40, Length = 200, Global step = 2340, Eps: 0.02
# Training: Episode = 41, Length = 200, Global step = 2540, Eps: 0.02
# Training: Episode = 42, Length = 200, Global step = 2740, Eps: 0.02
# Training: Episode = 43, Length = 200, Global step = 2940, Eps: 0.02
# Training: Episode = 44, Length = 200, Global step = 3140, Eps: 0.02
# Training: Episode = 45, Length = 200, Global step = 3340, Eps: 0.02
# Training: Episode = 46, Length = 200, Global step = 3540, Eps: 0.02
# Training: Episode = 47, Length = 200, Global step = 3740, Eps: 0.02
# Training: Episode = 48, Length = 200, Global step = 3940, Eps: 0.02
# Training: Episode = 49, Length = 200, Global step = 4140, Eps: 0.02
# Training: Episode = 50, Length = 200, Global step = 4340, Eps: 0.02
# Training: Episode = 51, Length = 200, Global step = 4540, Eps: 0.02
# Training: Episode = 52, Length = 200, Global step = 4740, Eps: 0.02
# Training: Episode = 53, Length = 200, Global step = 4940, Eps: 0.02
# Training: Episode = 54, Length = 200, Global step = 5140, Eps: 0.02
# Training: Episode = 55, Length = 200, Global step = 5340, Eps: 0.02
# Training: Episode = 56, Length = 200, Global step = 5540, Eps: 0.02
# Training: Episode = 57, Length = 31, Global step = 5571, Eps: 0.02
# Training: Episode = 58, Length = 11, Global step = 5582, Eps: 0.02
# Training: Episode = 59, Length = 200, Global step = 5782, Eps: 0.02
# Training: Episode = 60, Length = 28, Global step = 5810, Eps: 0.02
# Training: Episode = 61, Length = 10, Global step = 5820, Eps: 0.02
# Training: Episode = 62, Length = 200, Global step = 6020, Eps: 0.02
# Training: Episode = 63, Length = 200, Global step = 6220, Eps: 0.02
# Training: Episode = 64, Length = 29, Global step = 6249, Eps: 0.02
# Training: Episode = 65, Length = 200, Global step = 6449, Eps: 0.02
# Training: Episode = 66, Length = 11, Global step = 6460, Eps: 0.02
# Training: Episode = 67, Length = 200, Global step = 6660, Eps: 0.02
# Training: Episode = 68, Length = 200, Global step = 6860, Eps: 0.02
# Training: Episode = 69, Length = 200, Global step = 7060, Eps: 0.02
# Training: Episode = 70, Length = 11, Global step = 7071, Eps: 0.02
# Training: Episode = 71, Length = 10, Global step = 7081, Eps: 0.02
# Training: Episode = 72, Length = 11, Global step = 7092, Eps: 0.02
# Training: Episode = 73, Length = 11, Global step = 7103, Eps: 0.02
# Training: Episode = 74, Length = 10, Global step = 7113, Eps: 0.02
# Training: Episode = 75, Length = 10, Global step = 7123, Eps: 0.02
# Training: Episode = 76, Length = 11, Global step = 7134, Eps: 0.02
# Training: Episode = 77, Length = 10, Global step = 7144, Eps: 0.02
# Training: Episode = 78, Length = 11, Global step = 7155, Eps: 0.02
# Training: Episode = 79, Length = 29, Global step = 7184, Eps: 0.02
# Training: Episode = 80, Length = 200, Global step = 7384, Eps: 0.02
# Training: Episode = 81, Length = 200, Global step = 7584, Eps: 0.02
# Training: Episode = 82, Length = 200, Global step = 7784, Eps: 0.02
# Training: Episode = 83, Length = 200, Global step = 7984, Eps: 0.02
# Training: Episode = 84, Length = 200, Global step = 8184, Eps: 0.02
# Training: Episode = 85, Length = 200, Global step = 8384, Eps: 0.02
# Training: Episode = 86, Length = 200, Global step = 8584, Eps: 0.02
# Training: Episode = 87, Length = 200, Global step = 8784, Eps: 0.02
# Training: Episode = 88, Length = 200, Global step = 8984, Eps: 0.02
# Training: Episode = 89, Length = 200, Global step = 9184, Eps: 0.02
# Training: Episode = 90, Length = 200, Global step = 9384, Eps: 0.02
# Training: Episode = 91, Length = 200, Global step = 9584, Eps: 0.02
# Training: Episode = 92, Length = 10, Global step = 9594, Eps: 0.02
# Training: Episode = 93, Length = 200, Global step = 9794, Eps: 0.02
# Training: Episode = 94, Length = 200, Global step = 9994, Eps: 0.02
# Training: Episode = 95, Length = 31, Global step = 10025, Eps: 0.02
# Training: Episode = 96, Length = 200, Global step = 10225, Eps: 0.02
# Training: Episode = 97, Length = 200, Global step = 10425, Eps: 0.02
# Training: Episode = 98, Length = 200, Global step = 10625, Eps: 0.02
# Training: Episode = 99, Length = 200, Global step = 10825, Eps: 0.02
# Training: Episode = 100, Length = 200, Global step = 11025, Eps: 0.02
# Training: Episode = 101, Length = 200, Global step = 11225, Eps: 0.02
# Training: Episode = 102, Length = 200, Global step = 11425, Eps: 0.02
# Training: Episode = 103, Length = 200, Global step = 11625, Eps: 0.02
# Training: Episode = 104, Length = 168, Global step = 11793, Eps: 0.02
# Training: Episode = 105, Length = 59, Global step = 11852, Eps: 0.02
# Training: Episode = 106, Length = 10, Global step = 11862, Eps: 0.02
# Training: Episode = 107, Length = 9, Global step = 11871, Eps: 0.02
# Training: Episode = 108, Length = 8, Global step = 11879, Eps: 0.02
# Training: Episode = 109, Length = 9, Global step = 11888, Eps: 0.02
# Training: Episode = 110, Length = 9, Global step = 11897, Eps: 0.02
# Training: Episode = 111, Length = 9, Global step = 11906, Eps: 0.02
# Training: Episode = 112, Length = 10, Global step = 11916, Eps: 0.02
# Training: Episode = 113, Length = 9, Global step = 11925, Eps: 0.02
# Training: Episode = 114, Length = 10, Global step = 11935, Eps: 0.02
# Training: Episode = 115, Length = 8, Global step = 11943, Eps: 0.02
# Training: Episode = 116, Length = 11, Global step = 11954, Eps: 0.02
# Training: Episode = 117, Length = 10, Global step = 11964, Eps: 0.02
# Training: Episode = 118, Length = 13, Global step = 11977, Eps: 0.02
# Training: Episode = 119, Length = 11, Global step = 11988, Eps: 0.02
# Training: Episode = 120, Length = 13, Global step = 12001, Eps: 0.02
# Training: Episode = 121, Length = 30, Global step = 12031, Eps: 0.02
# Training: Episode = 122, Length = 200, Global step = 12231, Eps: 0.02
# Training: Episode = 123, Length = 200, Global step = 12431, Eps: 0.02
# Training: Episode = 124, Length = 200, Global step = 12631, Eps: 0.02
# Training: Episode = 125, Length = 200, Global step = 12831, Eps: 0.02
# Training: Episode = 126, Length = 192, Global step = 13023, Eps: 0.02
# Training: Episode = 127, Length = 128, Global step = 13151, Eps: 0.02
# Training: Episode = 128, Length = 80, Global step = 13231, Eps: 0.02
# Training: Episode = 129, Length = 10, Global step = 13241, Eps: 0.02
# Training: Episode = 130, Length = 200, Global step = 13441, Eps: 0.02
# Training: Episode = 131, Length = 13, Global step = 13454, Eps: 0.02
# Training: Episode = 132, Length = 193, Global step = 13647, Eps: 0.02
# Training: Episode = 133, Length = 56, Global step = 13703, Eps: 0.02
# Training: Episode = 134, Length = 9, Global step = 13712, Eps: 0.02
# Training: Episode = 135, Length = 200, Global step = 13912, Eps: 0.02
# Training: Episode = 136, Length = 200, Global step = 14112, Eps: 0.02
# Training: Episode = 137, Length = 10, Global step = 14122, Eps: 0.02
# Training: Episode = 138, Length = 12, Global step = 14134, Eps: 0.02
# Training: Episode = 139, Length = 11, Global step = 14145, Eps: 0.02
# Training: Episode = 140, Length = 11, Global step = 14156, Eps: 0.02
# Training: Episode = 141, Length = 10, Global step = 14166, Eps: 0.02
# Training: Episode = 142, Length = 14, Global step = 14180, Eps: 0.02
# Training: Episode = 143, Length = 11, Global step = 14191, Eps: 0.02
# Training: Episode = 144, Length = 12, Global step = 14203, Eps: 0.02
# Training: Episode = 145, Length = 13, Global step = 14216, Eps: 0.02
# Training: Episode = 146, Length = 13, Global step = 14229, Eps: 0.02
# Training: Episode = 147, Length = 200, Global step = 14429, Eps: 0.02
# Training: Episode = 148, Length = 200, Global step = 14629, Eps: 0.02
# Training: Episode = 149, Length = 200, Global step = 14829, Eps: 0.02
# Training: Episode = 150, Length = 200, Global step = 15029, Eps: 0.02
# Training: Episode = 151, Length = 200, Global step = 15229, Eps: 0.02
# Training: Episode = 152, Length = 200, Global step = 15429, Eps: 0.02
# Training: Episode = 153, Length = 200, Global step = 15629, Eps: 0.02
# Training: Episode = 154, Length = 200, Global step = 15829, Eps: 0.02
# Training: Episode = 155, Length = 11, Global step = 15840, Eps: 0.02
# Training: Episode = 156, Length = 200, Global step = 16040, Eps: 0.02
# Training: Episode = 157, Length = 13, Global step = 16053, Eps: 0.02
# Training: Episode = 158, Length = 200, Global step = 16253, Eps: 0.02
# Training: Episode = 159, Length = 200, Global step = 16453, Eps: 0.02
# Training: Episode = 160, Length = 200, Global step = 16653, Eps: 0.02
# Training: Episode = 161, Length = 200, Global step = 16853, Eps: 0.02
# Training: Episode = 162, Length = 200, Global step = 17053, Eps: 0.02
# Training: Episode = 163, Length = 200, Global step = 17253, Eps: 0.02
# Training: Episode = 164, Length = 200, Global step = 17453, Eps: 0.02
# Training: Episode = 165, Length = 200, Global step = 17653, Eps: 0.02
# Training: Episode = 166, Length = 200, Global step = 17853, Eps: 0.02
# Training: Episode = 167, Length = 200, Global step = 18053, Eps: 0.02
# Training: Episode = 168, Length = 200, Global step = 18253, Eps: 0.02
# Training: Episode = 169, Length = 155, Global step = 18408, Eps: 0.02
# Training: Episode = 170, Length = 200, Global step = 18608, Eps: 0.02
# Training: Episode = 171, Length = 66, Global step = 18674, Eps: 0.02
# Training: Episode = 172, Length = 200, Global step = 18874, Eps: 0.02
# Training: Episode = 173, Length = 200, Global step = 19074, Eps: 0.02
# Training: Episode = 174, Length = 200, Global step = 19274, Eps: 0.02
# Training: Episode = 175, Length = 126, Global step = 19400, Eps: 0.02
# Training: Episode = 176, Length = 127, Global step = 19527, Eps: 0.02
# Training: Episode = 177, Length = 66, Global step = 19593, Eps: 0.02
# Training: Episode = 178, Length = 103, Global step = 19696, Eps: 0.02
# Training: Episode = 179, Length = 139, Global step = 19835, Eps: 0.02
# Training: Episode = 180, Length = 90, Global step = 19925, Eps: 0.02
# Training: Episode = 181, Length = 10, Global step = 19935, Eps: 0.02
# Training: Episode = 182, Length = 200, Global step = 20135, Eps: 0.02
# Training: Episode = 183, Length = 200, Global step = 20335, Eps: 0.02
# Training: Episode = 184, Length = 200, Global step = 20535, Eps: 0.02
# Training: Episode = 185, Length = 200, Global step = 20735, Eps: 0.02
# Training: Episode = 186, Length = 200, Global step = 20935, Eps: 0.02
# Training: Episode = 187, Length = 200, Global step = 21135, Eps: 0.02
# Training: Episode = 188, Length = 200, Global step = 21335, Eps: 0.02
# Training: Episode = 189, Length = 200, Global step = 21535, Eps: 0.02
# Training: Episode = 190, Length = 200, Global step = 21735, Eps: 0.02
# Training: Episode = 191, Length = 200, Global step = 21935, Eps: 0.02
# Training: Episode = 192, Length = 200, Global step = 22135, Eps: 0.02
# Training: Episode = 193, Length = 9, Global step = 22144, Eps: 0.02
# Training: Episode = 194, Length = 48, Global step = 22192, Eps: 0.02
# Training: Episode = 195, Length = 200, Global step = 22392, Eps: 0.02
# Training: Episode = 196, Length = 65, Global step = 22457, Eps: 0.02
# Training: Episode = 197, Length = 200, Global step = 22657, Eps: 0.02
# Training: Episode = 198, Length = 62, Global step = 22719, Eps: 0.02
# Training: Episode = 199, Length = 200, Global step = 22919, Eps: 0.02
# Training: Episode = 200, Length = 200, Global step = 23119, Eps: 0.02
# Training: Episode = 201, Length = 200, Global step = 23319, Eps: 0.02
# Training: Episode = 202, Length = 200, Global step = 23519, Eps: 0.02
# Training: Episode = 203, Length = 10, Global step = 23529, Eps: 0.02
# Training: Episode = 204, Length = 200, Global step = 23729, Eps: 0.02
# Training: Episode = 205, Length = 200, Global step = 23929, Eps: 0.02
# Training: Episode = 206, Length = 200, Global step = 24129, Eps: 0.02
# Training: Episode = 207, Length = 200, Global step = 24329, Eps: 0.02
# Training: Episode = 208, Length = 200, Global step = 24529, Eps: 0.02
# Training: Episode = 209, Length = 200, Global step = 24729, Eps: 0.02
# Training: Episode = 210, Length = 200, Global step = 24929, Eps: 0.02
# Training: Episode = 211, Length = 200, Global step = 25129, Eps: 0.02
# Training: Episode = 212, Length = 200, Global step = 25329, Eps: 0.02
# Training: Episode = 213, Length = 200, Global step = 25529, Eps: 0.02
# Training: Episode = 214, Length = 200, Global step = 25729, Eps: 0.02
# Training: Episode = 215, Length = 200, Global step = 25929, Eps: 0.02
# Training: Episode = 216, Length = 200, Global step = 26129, Eps: 0.02
# Training: Episode = 217, Length = 200, Global step = 26329, Eps: 0.02
# Training: Episode = 218, Length = 200, Global step = 26529, Eps: 0.02
# Training: Episode = 219, Length = 200, Global step = 26729, Eps: 0.02
# Training: Episode = 220, Length = 200, Global step = 26929, Eps: 0.02
# Training: Episode = 221, Length = 200, Global step = 27129, Eps: 0.02
# Training: Episode = 222, Length = 200, Global step = 27329, Eps: 0.02
# Training: Episode = 223, Length = 200, Global step = 27529, Eps: 0.02
# Training: Episode = 224, Length = 200, Global step = 27729, Eps: 0.02
# Training: Episode = 225, Length = 200, Global step = 27929, Eps: 0.02
# Training: Episode = 226, Length = 200, Global step = 28129, Eps: 0.02
# Training: Episode = 227, Length = 70, Global step = 28199, Eps: 0.02
# Training: Episode = 228, Length = 9, Global step = 28208, Eps: 0.02
# Training: Episode = 229, Length = 35, Global step = 28243, Eps: 0.02
# Training: Episode = 230, Length = 24, Global step = 28267, Eps: 0.02
# Training: Episode = 231, Length = 43, Global step = 28310, Eps: 0.02
# Training: Episode = 232, Length = 49, Global step = 28359, Eps: 0.02
# Training: Episode = 233, Length = 38, Global step = 28397, Eps: 0.02
# Training: Episode = 234, Length = 29, Global step = 28426, Eps: 0.02
# Training: Episode = 235, Length = 10, Global step = 28436, Eps: 0.02
# Training: Episode = 236, Length = 23, Global step = 28459, Eps: 0.02
# Training: Episode = 237, Length = 10, Global step = 28469, Eps: 0.02
# Training: Episode = 238, Length = 10, Global step = 28479, Eps: 0.02
# Training: Episode = 239, Length = 9, Global step = 28488, Eps: 0.02
# Training: Episode = 240, Length = 10, Global step = 28498, Eps: 0.02
# Training: Episode = 241, Length = 8, Global step = 28506, Eps: 0.02
# Training: Episode = 242, Length = 9, Global step = 28515, Eps: 0.02
# Training: Episode = 243, Length = 10, Global step = 28525, Eps: 0.02
# Training: Episode = 244, Length = 9, Global step = 28534, Eps: 0.02
# Training: Episode = 245, Length = 11, Global step = 28545, Eps: 0.02
# Training: Episode = 246, Length = 9, Global step = 28554, Eps: 0.02
# Training: Episode = 247, Length = 9, Global step = 28563, Eps: 0.02
# Training: Episode = 248, Length = 10, Global step = 28573, Eps: 0.02
# Training: Episode = 249, Length = 12, Global step = 28585, Eps: 0.02
# Training: Episode = 250, Length = 9, Global step = 28594, Eps: 0.02
# Training: Episode = 251, Length = 12, Global step = 28606, Eps: 0.02
# Training: Episode = 252, Length = 10, Global step = 28616, Eps: 0.02
# Training: Episode = 253, Length = 12, Global step = 28628, Eps: 0.02
# Training: Episode = 254, Length = 42, Global step = 28670, Eps: 0.02
# Training: Episode = 255, Length = 200, Global step = 28870, Eps: 0.02
# Training: Episode = 256, Length = 200, Global step = 29070, Eps: 0.02
# Training: Episode = 257, Length = 200, Global step = 29270, Eps: 0.02
# Training: Episode = 258, Length = 200, Global step = 29470, Eps: 0.02
# Training: Episode = 259, Length = 200, Global step = 29670, Eps: 0.02
# Training: Episode = 260, Length = 200, Global step = 29870, Eps: 0.02
# Training: Episode = 261, Length = 200, Global step = 30070, Eps: 0.02
# Training: Episode = 262, Length = 200, Global step = 30270, Eps: 0.02
# Training: Episode = 263, Length = 200, Global step = 30470, Eps: 0.02
# Training: Episode = 264, Length = 200, Global step = 30670, Eps: 0.02
# Training: Episode = 265, Length = 200, Global step = 30870, Eps: 0.02
# Training: Episode = 266, Length = 200, Global step = 31070, Eps: 0.02
# Training: Episode = 267, Length = 200, Global step = 31270, Eps: 0.02
# Training: Episode = 268, Length = 200, Global step = 31470, Eps: 0.02
# Training: Episode = 269, Length = 200, Global step = 31670, Eps: 0.02
# Training: Episode = 270, Length = 200, Global step = 31870, Eps: 0.02
# Training: Episode = 271, Length = 200, Global step = 32070, Eps: 0.02
# Training: Episode = 272, Length = 200, Global step = 32270, Eps: 0.02
# Training: Episode = 273, Length = 200, Global step = 32470, Eps: 0.02
# Training: Episode = 274, Length = 200, Global step = 32670, Eps: 0.02
# Training: Episode = 275, Length = 200, Global step = 32870, Eps: 0.02
# Training: Episode = 276, Length = 200, Global step = 33070, Eps: 0.02
# Training: Episode = 277, Length = 200, Global step = 33270, Eps: 0.02
# Training: Episode = 278, Length = 200, Global step = 33470, Eps: 0.02
# Training: Episode = 279, Length = 200, Global step = 33670, Eps: 0.02
# Training: Episode = 280, Length = 200, Global step = 33870, Eps: 0.02
# Training: Episode = 281, Length = 200, Global step = 34070, Eps: 0.02
# Training: Episode = 282, Length = 200, Global step = 34270, Eps: 0.02
# Training: Episode = 283, Length = 200, Global step = 34470, Eps: 0.02
# Training: Episode = 284, Length = 200, Global step = 34670, Eps: 0.02
# Training: Episode = 285, Length = 200, Global step = 34870, Eps: 0.02
# Training: Episode = 286, Length = 200, Global step = 35070, Eps: 0.02
# Training: Episode = 287, Length = 200, Global step = 35270, Eps: 0.02
# Training: Episode = 288, Length = 200, Global step = 35470, Eps: 0.02
# Training: Episode = 289, Length = 200, Global step = 35670, Eps: 0.02
# Training: Episode = 290, Length = 200, Global step = 35870, Eps: 0.02
# Training: Episode = 291, Length = 200, Global step = 36070, Eps: 0.02
# Training: Episode = 292, Length = 200, Global step = 36270, Eps: 0.02
# Training: Episode = 293, Length = 200, Global step = 36470, Eps: 0.02
# Training: Episode = 294, Length = 200, Global step = 36670, Eps: 0.02
# Training: Episode = 295, Length = 200, Global step = 36870, Eps: 0.02
# Training: Episode = 296, Length = 200, Global step = 37070, Eps: 0.02
# Training: Episode = 297, Length = 200, Global step = 37270, Eps: 0.02
# Training: Episode = 298, Length = 200, Global step = 37470, Eps: 0.02
# Training: Episode = 299, Length = 200, Global step = 37670, Eps: 0.02
# Training: Episode = 300, Length = 200, Global step = 37870, Eps: 0.02
# Training: Episode = 301, Length = 200, Global step = 38070, Eps: 0.02
# Training: Episode = 302, Length = 200, Global step = 38270, Eps: 0.02
# Training: Episode = 303, Length = 200, Global step = 38470, Eps: 0.02
# Training: Episode = 304, Length = 200, Global step = 38670, Eps: 0.02
# Training: Episode = 305, Length = 200, Global step = 38870, Eps: 0.02
# Training: Episode = 306, Length = 41, Global step = 38911, Eps: 0.02
# Training: Episode = 307, Length = 8, Global step = 38919, Eps: 0.02
# Training: Episode = 308, Length = 9, Global step = 38928, Eps: 0.02
# Training: Episode = 309, Length = 200, Global step = 39128, Eps: 0.02
# Training: Episode = 310, Length = 37, Global step = 39165, Eps: 0.02
# Training: Episode = 311, Length = 135, Global step = 39300, Eps: 0.02
# Training: Episode = 312, Length = 200, Global step = 39500, Eps: 0.02
# Training: Episode = 313, Length = 200, Global step = 39700, Eps: 0.02
# Training: Episode = 314, Length = 200, Global step = 39900, Eps: 0.02
# Training: Episode = 315, Length = 200, Global step = 40100, Eps: 0.02
# Training: Episode = 316, Length = 200, Global step = 40300, Eps: 0.02
# Training: Episode = 317, Length = 200, Global step = 40500, Eps: 0.02
# Training: Episode = 318, Length = 200, Global step = 40700, Eps: 0.02
# Training: Episode = 319, Length = 200, Global step = 40900, Eps: 0.02
# Training: Episode = 320, Length = 200, Global step = 41100, Eps: 0.02
# Training: Episode = 321, Length = 200, Global step = 41300, Eps: 0.02
# Training: Episode = 322, Length = 200, Global step = 41500, Eps: 0.02
# Training: Episode = 323, Length = 41, Global step = 41541, Eps: 0.02
# Training: Episode = 324, Length = 200, Global step = 41741, Eps: 0.02
# Training: Episode = 325, Length = 200, Global step = 41941, Eps: 0.02
# Training: Episode = 326, Length = 200, Global step = 42141, Eps: 0.02
# Training: Episode = 327, Length = 47, Global step = 42188, Eps: 0.02
# Training: Episode = 328, Length = 200, Global step = 42388, Eps: 0.02
# Training: Episode = 329, Length = 48, Global step = 42436, Eps: 0.02
# Training: Episode = 330, Length = 49, Global step = 42485, Eps: 0.02
# Training: Episode = 331, Length = 55, Global step = 42540, Eps: 0.02
# Training: Episode = 332, Length = 33, Global step = 42573, Eps: 0.02
# Training: Episode = 333, Length = 53, Global step = 42626, Eps: 0.02
# Training: Episode = 334, Length = 46, Global step = 42672, Eps: 0.02
# Training: Episode = 335, Length = 30, Global step = 42702, Eps: 0.02
# Training: Episode = 336, Length = 22, Global step = 42724, Eps: 0.02
# Training: Episode = 337, Length = 13, Global step = 42737, Eps: 0.02
# Training: Episode = 338, Length = 13, Global step = 42750, Eps: 0.02
# Training: Episode = 339, Length = 15, Global step = 42765, Eps: 0.02
# Training: Episode = 340, Length = 48, Global step = 42813, Eps: 0.02
# Training: Episode = 341, Length = 61, Global step = 42874, Eps: 0.02
# Training: Episode = 342, Length = 200, Global step = 43074, Eps: 0.02
# Training: Episode = 343, Length = 200, Global step = 43274, Eps: 0.02
# Training: Episode = 344, Length = 200, Global step = 43474, Eps: 0.02
# Training: Episode = 345, Length = 200, Global step = 43674, Eps: 0.02
# Training: Episode = 346, Length = 200, Global step = 43874, Eps: 0.02
# Training: Episode = 347, Length = 200, Global step = 44074, Eps: 0.02
# Training: Episode = 348, Length = 200, Global step = 44274, Eps: 0.02
# Training: Episode = 349, Length = 200, Global step = 44474, Eps: 0.02
# Training: Episode = 350, Length = 200, Global step = 44674, Eps: 0.02
# Training: Episode = 351, Length = 200, Global step = 44874, Eps: 0.02
# Training: Episode = 352, Length = 200, Global step = 45074, Eps: 0.02
# Training: Episode = 353, Length = 200, Global step = 45274, Eps: 0.02
# Training: Episode = 354, Length = 200, Global step = 45474, Eps: 0.02
# Training: Episode = 355, Length = 200, Global step = 45674, Eps: 0.02
# Training: Episode = 356, Length = 200, Global step = 45874, Eps: 0.02
# Training: Episode = 357, Length = 200, Global step = 46074, Eps: 0.02
# Training: Episode = 358, Length = 200, Global step = 46274, Eps: 0.02
# Training: Episode = 359, Length = 200, Global step = 46474, Eps: 0.02
# Training: Episode = 360, Length = 200, Global step = 46674, Eps: 0.02
# Training: Episode = 361, Length = 200, Global step = 46874, Eps: 0.02
# Training: Episode = 362, Length = 200, Global step = 47074, Eps: 0.02
# Training: Episode = 363, Length = 200, Global step = 47274, Eps: 0.02
# Training: Episode = 364, Length = 200, Global step = 47474, Eps: 0.02
# Training: Episode = 365, Length = 200, Global step = 47674, Eps: 0.02
# Training: Episode = 366, Length = 200, Global step = 47874, Eps: 0.02
# Training: Episode = 367, Length = 200, Global step = 48074, Eps: 0.02
# Training: Episode = 368, Length = 200, Global step = 48274, Eps: 0.02
# Training: Episode = 369, Length = 200, Global step = 48474, Eps: 0.02
# Training: Episode = 370, Length = 200, Global step = 48674, Eps: 0.02
# Training: Episode = 371, Length = 200, Global step = 48874, Eps: 0.02
# Training: Episode = 372, Length = 200, Global step = 49074, Eps: 0.02
# Training: Episode = 373, Length = 200, Global step = 49274, Eps: 0.02
# Training: Episode = 374, Length = 200, Global step = 49474, Eps: 0.02
# Training: Episode = 375, Length = 200, Global step = 49674, Eps: 0.02
# Training: Episode = 376, Length = 200, Global step = 49874, Eps: 0.02
# Training: Episode = 377, Length = 200, Global step = 50074, Eps: 0.02
# Training: Episode = 378, Length = 200, Global step = 50274, Eps: 0.02
# Training: Episode = 379, Length = 200, Global step = 50474, Eps: 0.02
# Training: Episode = 380, Length = 200, Global step = 50674, Eps: 0.02
# Training: Episode = 381, Length = 200, Global step = 50874, Eps: 0.02
# Training: Episode = 382, Length = 200, Global step = 51074, Eps: 0.02
# Training: Episode = 383, Length = 200, Global step = 51274, Eps: 0.02
# Training: Episode = 384, Length = 200, Global step = 51474, Eps: 0.02
# Training: Episode = 385, Length = 200, Global step = 51674, Eps: 0.02
# Training: Episode = 386, Length = 200, Global step = 51874, Eps: 0.02
# Training: Episode = 387, Length = 200, Global step = 52074, Eps: 0.02
# Training: Episode = 388, Length = 200, Global step = 52274, Eps: 0.02
# Training: Episode = 389, Length = 200, Global step = 52474, Eps: 0.02
# Training: Episode = 390, Length = 200, Global step = 52674, Eps: 0.02
# Training: Episode = 391, Length = 200, Global step = 52874, Eps: 0.02
# Training: Episode = 392, Length = 200, Global step = 53074, Eps: 0.02
# Training: Episode = 393, Length = 200, Global step = 53274, Eps: 0.02
# Training: Episode = 394, Length = 200, Global step = 53474, Eps: 0.02
# Training: Episode = 395, Length = 200, Global step = 53674, Eps: 0.02
# Training: Episode = 396, Length = 200, Global step = 53874, Eps: 0.02
# Training: Episode = 397, Length = 200, Global step = 54074, Eps: 0.02
# Training: Episode = 398, Length = 200, Global step = 54274, Eps: 0.02
# Training: Episode = 399, Length = 200, Global step = 54474, Eps: 0.02
# Training: Episode = 400, Length = 200, Global step = 54674, Eps: 0.02
# Training: Episode = 401, Length = 200, Global step = 54874, Eps: 0.02
# Training: Episode = 402, Length = 200, Global step = 55074, Eps: 0.02
# Training: Episode = 403, Length = 200, Global step = 55274, Eps: 0.02
# Training: Episode = 404, Length = 200, Global step = 55474, Eps: 0.02
# Training: Episode = 405, Length = 200, Global step = 55674, Eps: 0.02
# Training: Episode = 406, Length = 200, Global step = 55874, Eps: 0.02
# Training: Episode = 407, Length = 200, Global step = 56074, Eps: 0.02
# Training: Episode = 408, Length = 200, Global step = 56274, Eps: 0.02
# Training: Episode = 409, Length = 200, Global step = 56474, Eps: 0.02
# Training: Episode = 410, Length = 200, Global step = 56674, Eps: 0.02
# Training: Episode = 411, Length = 200, Global step = 56874, Eps: 0.02
# Training: Episode = 412, Length = 200, Global step = 57074, Eps: 0.02
# Training: Episode = 413, Length = 200, Global step = 57274, Eps: 0.02
# Training: Episode = 414, Length = 13, Global step = 57287, Eps: 0.02
# Training: Episode = 415, Length = 200, Global step = 57487, Eps: 0.02
# Training: Episode = 416, Length = 12, Global step = 57499, Eps: 0.02
# Training: Episode = 417, Length = 200, Global step = 57699, Eps: 0.02
# Training: Episode = 418, Length = 200, Global step = 57899, Eps: 0.02
# Training: Episode = 419, Length = 200, Global step = 58099, Eps: 0.02
# Training: Episode = 420, Length = 200, Global step = 58299, Eps: 0.02
# Training: Episode = 421, Length = 200, Global step = 58499, Eps: 0.02
# Training: Episode = 422, Length = 13, Global step = 58512, Eps: 0.02
# Training: Episode = 423, Length = 200, Global step = 58712, Eps: 0.02
# Training: Episode = 424, Length = 200, Global step = 58912, Eps: 0.02
# Training: Episode = 425, Length = 200, Global step = 59112, Eps: 0.02
# Training: Episode = 426, Length = 200, Global step = 59312, Eps: 0.02
# Training: Episode = 427, Length = 200, Global step = 59512, Eps: 0.02
# Training: Episode = 428, Length = 200, Global step = 59712, Eps: 0.02
# Training: Episode = 429, Length = 200, Global step = 59912, Eps: 0.02
# Training: Episode = 430, Length = 200, Global step = 60112, Eps: 0.02
# Training: Episode = 431, Length = 200, Global step = 60312, Eps: 0.02
# Training: Episode = 432, Length = 200, Global step = 60512, Eps: 0.02
# Training: Episode = 433, Length = 200, Global step = 60712, Eps: 0.02
# Training: Episode = 434, Length = 200, Global step = 60912, Eps: 0.02
# Training: Episode = 435, Length = 200, Global step = 61112, Eps: 0.02
# Training: Episode = 436, Length = 200, Global step = 61312, Eps: 0.02
# Training: Episode = 437, Length = 200, Global step = 61512, Eps: 0.02
# Training: Episode = 438, Length = 200, Global step = 61712, Eps: 0.02
# Training: Episode = 439, Length = 200, Global step = 61912, Eps: 0.02
# Training: Episode = 440, Length = 200, Global step = 62112, Eps: 0.02
# Training: Episode = 441, Length = 200, Global step = 62312, Eps: 0.02
# Training: Episode = 442, Length = 200, Global step = 62512, Eps: 0.02
# Training: Episode = 443, Length = 200, Global step = 62712, Eps: 0.02
# Training: Episode = 444, Length = 200, Global step = 62912, Eps: 0.02
# Training: Episode = 445, Length = 200, Global step = 63112, Eps: 0.02
# Training: Episode = 446, Length = 200, Global step = 63312, Eps: 0.02
# Training: Episode = 447, Length = 200, Global step = 63512, Eps: 0.02
# Training: Episode = 448, Length = 200, Global step = 63712, Eps: 0.02
# Training: Episode = 449, Length = 200, Global step = 63912, Eps: 0.02
# Training: Episode = 450, Length = 200, Global step = 64112, Eps: 0.02
# Training: Episode = 451, Length = 200, Global step = 64312, Eps: 0.02
# Training: Episode = 452, Length = 200, Global step = 64512, Eps: 0.02
# Training: Episode = 453, Length = 200, Global step = 64712, Eps: 0.02
# Training: Episode = 454, Length = 200, Global step = 64912, Eps: 0.02
# Training: Episode = 455, Length = 200, Global step = 65112, Eps: 0.02
# Training: Episode = 456, Length = 200, Global step = 65312, Eps: 0.02
# Training: Episode = 457, Length = 200, Global step = 65512, Eps: 0.02
# Training: Episode = 458, Length = 200, Global step = 65712, Eps: 0.02
# Training: Episode = 459, Length = 200, Global step = 65912, Eps: 0.02
# Training: Episode = 460, Length = 200, Global step = 66112, Eps: 0.02
# Training: Episode = 461, Length = 200, Global step = 66312, Eps: 0.02
# Training: Episode = 462, Length = 200, Global step = 66512, Eps: 0.02
# Training: Episode = 463, Length = 200, Global step = 66712, Eps: 0.02
# Training: Episode = 464, Length = 200, Global step = 66912, Eps: 0.02
# Training: Episode = 465, Length = 200, Global step = 67112, Eps: 0.02
# Training: Episode = 466, Length = 200, Global step = 67312, Eps: 0.02
# Training: Episode = 467, Length = 200, Global step = 67512, Eps: 0.02
# Training: Episode = 468, Length = 10, Global step = 67522, Eps: 0.02
# Training: Episode = 469, Length = 8, Global step = 67530, Eps: 0.02
# Training: Episode = 470, Length = 9, Global step = 67539, Eps: 0.02
# Training: Episode = 471, Length = 9, Global step = 67548, Eps: 0.02
# Training: Episode = 472, Length = 9, Global step = 67557, Eps: 0.02
# Training: Episode = 473, Length = 9, Global step = 67566, Eps: 0.02
# Training: Episode = 474, Length = 10, Global step = 67576, Eps: 0.02
# Training: Episode = 475, Length = 9, Global step = 67585, Eps: 0.02
# Training: Episode = 476, Length = 8, Global step = 67593, Eps: 0.02
# Training: Episode = 477, Length = 10, Global step = 67603, Eps: 0.02
# Training: Episode = 478, Length = 11, Global step = 67614, Eps: 0.02
# Training: Episode = 479, Length = 8, Global step = 67622, Eps: 0.02
# Training: Episode = 480, Length = 9, Global step = 67631, Eps: 0.02
# Training: Episode = 481, Length = 9, Global step = 67640, Eps: 0.02
# Training: Episode = 482, Length = 9, Global step = 67649, Eps: 0.02
# Training: Episode = 483, Length = 10, Global step = 67659, Eps: 0.02
# Training: Episode = 484, Length = 10, Global step = 67669, Eps: 0.02
# Training: Episode = 485, Length = 8, Global step = 67677, Eps: 0.02
# Training: Episode = 486, Length = 10, Global step = 67687, Eps: 0.02
# Training: Episode = 487, Length = 10, Global step = 67697, Eps: 0.02
# Training: Episode = 488, Length = 9, Global step = 67706, Eps: 0.02
# Training: Episode = 489, Length = 10, Global step = 67716, Eps: 0.02
# Training: Episode = 490, Length = 9, Global step = 67725, Eps: 0.02
# Training: Episode = 491, Length = 10, Global step = 67735, Eps: 0.02
# Training: Episode = 492, Length = 10, Global step = 67745, Eps: 0.02
# Training: Episode = 493, Length = 11, Global step = 67756, Eps: 0.02
# Training: Episode = 494, Length = 13, Global step = 67769, Eps: 0.02
# Training: Episode = 495, Length = 11, Global step = 67780, Eps: 0.02
# Training: Episode = 496, Length = 35, Global step = 67815, Eps: 0.02
# Training: Episode = 497, Length = 37, Global step = 67852, Eps: 0.02
# Training: Episode = 498, Length = 200, Global step = 68052, Eps: 0.02
# Training: Episode = 499, Length = 200, Global step = 68252, Eps: 0.02
#
# Finished training...
# Check out some demonstrations

# %%
# average steps
results = []
for i in range(50):
    episode_length = dqn.playPolicy()
    print("Test steps = ", episode_length)
    results.append(episode_length)
print("Mean steps = ", sum(results) / len(results))	
dqn.env.close()
print("\nFinished.")
print("\nCiao, and hasta la vista...\n")
# Out:
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Test steps =  200
# Mean steps =  200.0
#
# Finished.
#
# Ciao, and hasta la vista...

# %%
m = 100
n = len(dqn.episodic_rewards)//m
ep_rwd = np.reshape(dqn.episodic_rewards[:n*m],(n,m))
avg_eprwd = np.mean(ep_rwd,axis=1)
x_plot = [(i+1)*m for i in range(n)]
plt.plot(x_plot, avg_eprwd)
plt.xlabel('Episodes')
plt.ylabel('Average Reward for every '+str(m)+' Episodes')
plt.title('DQN with out replay buffer, Cart-pole')
plt.show()

# %%
dqn.save_model('dqn_weights_without_replay_buffer')
np.save('dqn_weights_without_replay_buffer.npy',dqn.episodic_rewards)
# Out:
# WARNING:tensorflow:From /home/subbu/.local/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: dqn_weights_without_replay_buffer/assets

# %%
# to visualize it

dqn_vis = DQN('CartPole-v0')
dqn_vis.load_model('dqn_weights_without_replay_buffer') # loading trained model from memory
for i in range(10):
    done = False
    steps = 0
    state = dqn_vis.env.reset()

    while not done and steps < 200: 
        dqn_vis.env.render()
        action = np.argmax(dqn_vis.model.predict(np.array([state]))[0])
        state, _, done, _ = dqn_vis.env.step(action)
        steps += 1
        
    print('Steps:'+str(steps))

dqn_vis.env.close()
# Out:
# Steps:200
# Steps:200
# Steps:200
# Steps:200
# Steps:200
# Steps:200
# Steps:200
# Steps:200
# Steps:200
# Steps:200

# %%
# to visualize it No need to train again

ep_rwd = np.load('dqn_weights_without_replay_buffer.npy') # loading training data from memory
avg_eprwd = []
tot = 0
for i in range(1,100):
    avg_eprwd.append(tot/i)
    tot += ep_rwd[i]
for i in range(100,len(ep_rwd)):
    tot += ep_rwd[i]
    tot -= ep_rwd[i-100]
    avg_eprwd.append(tot/100)
plt.plot(ep_rwd,'c',linewidth=0.3)
plt.plot(avg_eprwd,'b',linewidth=2)
plt.xlabel('Episodes')
plt.ylabel('Average Reward for every '+str(100)+' Episodes')
plt.title('DQN, Cart-pole')
plt.show()
